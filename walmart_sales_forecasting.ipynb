# %% [markdown]
# Import all the required libraries

# %%
import pandas as pd
import datetime                                        # To handle dates
import calendar                                        # To get month
import statsmodels.formula.api as sm
import matplotlib.pylab as plt
import numpy as np
import seaborn as sns
import sklearn.metrics as metrics                      # To get regression metrics
import scipy as sp
import time                                            # To do time complexity analysis
import random
import copy
import profile
import cProfile
from sklearn.cluster import KMeans                     # perform clustering operation
# %matplotlib inline

# %%
#import os
#os.chdir("/Users/janhavigulabani/Desktop/walmart")

# %% [markdown]
# Create Master Data Set and initial analysis
#
# Read all data

# %%
#loading in raw data
features_df = pd.read_csv("features.csv")
stores_df = pd.read_csv("stores.csv")
train_df = pd.read_csv("train.csv")

# %%
features_df.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
features_df.describe()
# Out:
#              Store  Temperature   Fuel_Price      MarkDown1      MarkDown2  \
# count  8190.000000  8190.000000  8190.000000    4032.000000    2921.000000
# mean     23.000000    59.356198     3.405992    7032.371786    3384.176594
# std      12.987966    18.678607     0.431337    9262.747448    8793.583016
# min       1.000000    -7.290000     2.472000   -2781.450000    -265.760000
# 25%      12.000000    45.902500     3.041000    1577.532500      68.880000
# 50%      23.000000    60.710000     3.513000    4743.580000     364.570000
# 75%      34.000000    73.880000     3.743000    8923.310000    2153.350000
# max      45.000000   101.950000     4.468000  103184.980000  104519.540000
#
#            MarkDown3     MarkDown4      MarkDown5          CPI  Unemployment
# count    3613.000000   3464.000000    4050.000000  7605.000000   7605.000000
# mean     1760.100180   3292.935886    4132.216422   172.460809      7.826821
# std     11276.462208   6792.329861   13086.690278    39.738346      1.877259
# min      -179.260000      0.220000    -185.170000   126.064000      3.684000
# 25%         6.600000    304.687500    1440.827500   132.364839      6.634000
# 50%        36.260000   1176.425000    2727.135000   182.764003      7.806000
# 75%       163.150000   3310.007500    4832.555000   213.932412      8.567000
# max    149483.310000  67474.850000  771448.100000   228.976456     14.313000

# %%
stores_df.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
stores_df.describe()
# Out:
#            Store           Size
# count  45.000000      45.000000
# mean   23.000000  130287.600000
# std    13.133926   63825.271991
# min     1.000000   34875.000000
# 25%    12.000000   70713.000000
# 50%    23.000000  126512.000000
# 75%    34.000000  202307.000000
# max    45.000000  219622.000000

# %%
train_df.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  2010-02-05      24924.50      False
# 1      1     1  2010-02-12      46039.49       True
# 2      1     1  2010-02-19      41595.55      False
# 3      1     1  2010-02-26      19403.54      False
# 4      1     1  2010-03-05      21827.90      False

# %%
train_df.describe()
# Out:
#                Store           Dept   Weekly_Sales
# count  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123
# std        12.785297      30.492054   22711.183519
# min         1.000000       1.000000   -4988.940000
# 25%        11.000000      18.000000    2079.650000
# 50%        22.000000      37.000000    7612.030000
# 75%        33.000000      74.000000   20205.852500
# max        45.000000      99.000000  693099.360000

# %%
# Creating a custom season dictionary to identify the season in each month
seasons_dict = {
    1:"Winter",
    2:"Winter",
    3:"Spring",
    4:"Spring",
    5:"Spring",
    6:"Summer",
    7:"Summer",
    8:"Summer",
    9:"Fall",
    10:"Fall",
    11:"Fall",
    12:"Winter"
}

# %%
# Creating the master dataset
master_df = train_df.merge(stores_df, on='Store', how='left')
master_df = master_df.merge(features_df, on=['Store', 'Date'], how='left')

# %% [markdown]
# Preliminary Analysis

# %%
d = copy.deepcopy(master_df)

d1 = d["Weekly_Sales"]

print(d["Weekly_Sales"].describe())

print("Percentile less than 3% provides only negative value : ",d["Weekly_Sales"].quantile(0.003))
# Out:
# count    421570.000000
# mean      15981.258123
# std       22711.183519
# min       -4988.940000
# 25%        2079.650000
# 50%        7612.030000
# 75%       20205.852500
# max      693099.360000
# Name: Weekly_Sales, dtype: float64
# Percentile less than 3% provides only negative value :  -0.56

# %%
x = np.concatenate((d1[d["Weekly_Sales"] < 0], d1[d["Weekly_Sales"] > 0]))

plt.hist(x, density=True)

plt.xlim([-70496, 200000])
plt.xlabel('Weekly Sales Values')
plt.ylabel('Normalized Sales Values')
plt.title('Normalized distribution of sales values')
plt.show()

# %% [markdown]
# As can be seen, there are some erroneous recording of sales. The sales can not be negative for a particular month, as illustrated in the graph. In the later section we clean the data to remove negative sales

# %% [markdown]
# Data Cleaning

# %%
# Filling empty markdown columns
master_df['MarkDown1'] = master_df['MarkDown1'].fillna(0)
master_df['MarkDown2'] = master_df['MarkDown2'].fillna(0)
master_df['MarkDown3'] = master_df['MarkDown3'].fillna(0)
master_df['MarkDown4'] = master_df['MarkDown4'].fillna(0)
master_df['MarkDown5'] = master_df['MarkDown5'].fillna(0)

# Cleaning holiday columns
master_df['isHoliday'] = master_df['IsHoliday_x']
master_df = master_df.drop(columns=['IsHoliday_x', 'IsHoliday_y'])

# %%
# Handling Date and time
master_df['Date'] = pd.to_datetime(master_df['Date'], format='%Y-%m-%d')
master_df['Week_Number'] = master_df['Date'].dt.week
master_df['Quarter'] = master_df['Date'].dt.quarter
master_df['Month'] = master_df['Date'].dt.month.apply(lambda x: calendar.month_abbr[x])
master_df['Season'] = (master_df['Date'].apply(lambda dt: (dt.month%12 + 3)//3)).map(seasons_dict)
master_df["Year"] = master_df["Date"].dt.year
# Out:
# /var/folders/81/8tq9rszx7vs5py4pq8yqqsdc0000gn/T/ipykernel_6530/3476480186.py:3: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   master_df['Week_Number'] = master_df['Date'].dt.week

# %% [markdown]
# Creating lagged variables based on time

# %%
master_df=master_df.sort_values(by=['Store', 'Dept', 'Year', 'Week_Number'], ascending=True)    

# Previous week sales
shifted_sales = master_df.shift(1)
master_df_new_var = master_df.join(shifted_sales[['Store', 'Dept', 'Week_Number', 'Weekly_Sales', 'Year']], rsuffix='_Lag')
master_df_new_var.loc[(master_df_new_var.Dept != master_df_new_var.Dept_Lag) |  (master_df_new_var.Store != master_df_new_var.Store_Lag), 'Weekly_Sales_Lag'] = -2

# Previous month sales
#shifted_sales = master_df.shift(4)
#master_df_new_var = master_df_new_var.join(shifted_sales[['Store', 'Dept', 'Week_Number', 'Weekly_Sales', 'Year']], rsuffix='_Lag2')
#master_df_new_var['Monthly_Sales_Lag'] = master_df_new_var.Week_Number_Lag2
#master_df_new_var.loc[((master_df_new_var.Week_Number - master_df_new_var.Week_Number_Lag2) != 4) , 'Monthly_Sales_Lag'] = 0
#master_df_new_var[['Store', 'Dept', 'Week_Number', 'Weekly_Sales', 'Year', 'Weekly_Sales_Lag']]

# Average yearly sales
#my_df= master_df[['Store','Dept','Week_Number','Weekly_Sales']]
#my_df2= my_df.groupby(['Store','Dept','Week_Number']).mean()
#master_df.set_index(['Store','Dept','Week_Number'],inplace= True)
#df=master_df.join(my_df2, rsuffix='_yearly').reset_index(inplace=True)
#master_df_new_var['Yearly_Sales']=df['Weekly_Sales_yearly']

# %% [markdown]
# Lagged time varibles play a significant role in explaining current trends and seasonal pattern which repeat over a period of time. Furthermore lag variables capture the inherent store features which can get little tricky to zero out

# %% [markdown]
# Creating dummy variables for categorical values

# %%
#forming categorarical variables
master_df_new_var = master_df_new_var.join(pd.get_dummies(master_df['Quarter'], prefix='Quarter'))
master_df_new_var = master_df_new_var.join(pd.get_dummies(master_df['Season'], prefix='Season'))
master_df_new_var = master_df_new_var.join(pd.get_dummies(master_df['Store'], prefix='Store'))
master_df_new_var = master_df_new_var.join(pd.get_dummies(master_df['Dept'], prefix='Dept'))
master_df_new_var = master_df_new_var.join(pd.get_dummies(master_df['Type'], prefix='Type'))
master_df_new_var = master_df_new_var.join(pd.get_dummies(master_df['Week_Number'], prefix='Week_Number'))

# %%
# Removing wrongly recorded data points
master_df_new_var = master_df_new_var.dropna()
#master_df_new_var = master_df_new_var.loc[master_df_new_var['Week_Number'] > 4]
#master_df_new_var = master_df_new_var.loc[master_df_new_var['Monthly_Sales_Lag'] > 0]
master_df_new_var = master_df_new_var.loc[master_df_new_var['Weekly_Sales_Lag'] > 0]
master_df_new_var = master_df_new_var.loc[master_df_new_var['Weekly_Sales'] > 0] #keeping points which are only positive in value for the sales

# %%
master_df_new_var['MarkDown'] = master_df_new_var['MarkDown1'] + master_df_new_var['MarkDown2'] + master_df_new_var['MarkDown3'] + master_df_new_var['MarkDown4'] + master_df_new_var['MarkDown5']
master_df_new_var['MarkDown*Weekly_Sales_Lag'] = master_df_new_var['MarkDown']*master_df_new_var['Weekly_Sales_Lag']

# %% [markdown]
# We created an interaction variable as promotional offers (markdown) and weekly sales go hand in hand. They together explain the future weekly sales in a very robust fashion
#
# Dividing the dataset into test and train dataset
#
# We will do an out of time validation. The model will be trained on first two years data and tested on the last six months data.

# %%
#segregating the data
data_test = master_df_new_var[master_df_new_var.Year == 2012]
data_train = master_df_new_var[master_df_new_var.Year != 2012]

# %% [markdown]
# Building full model linear regression

# %%
features = list(master_df_new_var)
for x in ('Quarter',
 'Month',
 'Season',
 'Year',
 'Store',
 'Dept',
 'Date',
 'Type',
 'Weekly_Sales',
 'Weekly_Sales_Lag'):
    features.remove(x)
#features

# %%
# Writing the formula
equals_to_str = ""
for i in features:
    equals_to_str = equals_to_str + str(i) + " + "

equals_to_str = str('Weekly_Sales ~ ') + equals_to_str
equals_to_str = equals_to_str[:-3] 
equals_to_str_promotion = equals_to_str + "Markdown1"

# %%
result_fullmodel = sm.ols(formula=equals_to_str, data = data_train).fit()
print("Model 1 without Promotion \n",result_fullmodel.summary())
# Out:
# Model 1 without Promotion
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           Weekly_Sales   R-squared:                       0.895
# Model:                            OLS   Adj. R-squared:                  0.895
# Method:                 Least Squares   F-statistic:                 1.301e+04
# Date:                Wed, 16 Nov 2022   Prob (F-statistic):               0.00
# Time:                        20:07:01   Log-Likelihood:            -2.9899e+06
# No. Observations:              289299   AIC:                         5.980e+06
# Df Residuals:                  289109   BIC:                         5.982e+06
# Df Model:                         189
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                 -1.854e+05   1.04e+05     -1.777      0.076    -3.9e+05    1.91e+04
# isHoliday[T.True]          3135.1986   2311.449      1.356      0.175   -1395.177    7665.574
# Size                         -0.2797      0.170     -1.647      0.100      -0.613       0.053
# Temperature                   3.5664      3.143      1.135      0.257      -2.594       9.727
# Fuel_Price                 -427.6665    126.459     -3.382      0.001    -675.523    -179.810
# MarkDown1                     0.0638      0.018      3.546      0.000       0.029       0.099
# MarkDown2                     0.0534      0.012      4.592      0.000       0.031       0.076
# MarkDown3                     0.0691      0.012      6.000      0.000       0.047       0.092
# MarkDown4                    -0.0443      0.034     -1.290      0.197      -0.112       0.023
# MarkDown5                     0.0013      0.014      0.087      0.930      -0.027       0.030
# CPI                          10.3677     19.796      0.524      0.600     -28.432      49.167
# Unemployment               -221.7131     53.176     -4.169      0.000    -325.936    -117.490
# Week_Number               -1868.1266   1043.931     -1.790      0.074   -3914.203     177.950
# Store_Lag                  -970.5814    555.505     -1.747      0.081   -2059.357     118.194
# Dept_Lag                   -113.8414     69.556     -1.637      0.102    -250.170      22.487
# Week_Number_Lag              11.4690     13.855      0.828      0.408     -15.686      38.624
# Year_Lag                    253.2185    143.744      1.762      0.078     -28.516     534.953
# Quarter_1                  -8.11e+04   4.57e+04     -1.775      0.076   -1.71e+05    8428.147
# Quarter_2                 -5.856e+04    3.3e+04     -1.776      0.076   -1.23e+05    6083.416
# Quarter_3                  -2.31e+04   1.28e+04     -1.798      0.072   -4.83e+04    2074.162
# Quarter_4                 -2.265e+04   1.28e+04     -1.763      0.078   -4.78e+04    2536.544
# Season_Spring             -9.448e+04   5.33e+04     -1.773      0.076   -1.99e+05    9979.266
# Season_Winter             -9.092e+04   5.11e+04     -1.781      0.075   -1.91e+05    9140.440
# Store_1                   -3.027e+04   1.69e+04     -1.788      0.074   -6.34e+04    2907.697
# Store_2                   -1.412e+04   7725.800     -1.828      0.068   -2.93e+04    1017.584
# Store_3                   -3.877e+04   2.12e+04     -1.833      0.067   -8.02e+04    2689.254
# Store_4                   -1.025e+04   7094.521     -1.445      0.148   -2.42e+04    3652.449
# Store_5                   -3.788e+04   2.05e+04     -1.849      0.064    -7.8e+04    2270.236
# Store_6                   -1.122e+04   5438.501     -2.063      0.039   -2.19e+04    -562.857
# Store_7                   -2.446e+04   1.36e+04     -1.798      0.072   -5.11e+04    2207.964
# Store_8                   -2.411e+04   1.23e+04     -1.955      0.051   -4.83e+04      62.445
# Store_9                   -8101.3226   2861.838     -2.831      0.005   -1.37e+04   -2492.200
# Store_10                  -2335.7149   3302.380     -0.707      0.479   -8808.287    4136.857
# Store_11                  -5383.5052   1876.042     -2.870      0.004   -9060.496   -1706.515
# Store_12                  -5234.3863   4693.284     -1.115      0.265   -1.44e+04    3964.320
# Store_13                   2402.0157    800.322      3.001      0.003     833.406    3970.625
# Store_14                  -1918.2520   1650.692     -1.162      0.245   -5153.563    1317.059
# Store_15                  -1259.7602    988.250     -1.275      0.202   -3196.703     677.183
# Store_16                  -2.009e+04   1.09e+04     -1.850      0.064   -4.14e+04    1200.127
# Store_17                  -7609.0130   5028.160     -1.513      0.130   -1.75e+04    2246.041
# Store_18                   1979.3575    566.121      3.496      0.000     869.776    3088.939
# Store_19                   2799.6173   1198.775      2.335      0.020     450.052    5149.183
# Store_20                   4288.2056   2532.356      1.693      0.090    -675.141    9251.553
# Store_21                   8473.0092   6298.336      1.345      0.179   -3871.554    2.08e+04
# Store_22                   5215.2701   2408.057      2.166      0.030     495.545    9934.995
# Store_23                   4878.1188   2144.539      2.275      0.023     674.881    9081.356
# Store_24                   7500.0712   3840.086      1.953      0.051     -26.390     1.5e+04
# Store_25                   8922.6154   6409.272      1.392      0.164   -3639.380    2.15e+04
# Store_26                  -5775.8133   3857.209     -1.497      0.134   -1.33e+04    1784.209
# Store_27                   1.132e+04   5602.639      2.021      0.043     340.940    2.23e+04
# Store_28                   1.322e+04   6294.495      2.100      0.036     879.202    2.56e+04
# Store_29                   4127.0483   1822.587      2.264      0.024     554.829    7699.267
# Store_30                  -1.965e+04   1.01e+04     -1.950      0.051   -3.94e+04      96.627
# Store_31                   1.325e+04   8672.063      1.528      0.126   -3745.200    3.02e+04
# Store_32                     1.4e+04   8798.819      1.591      0.112   -3246.260    3.12e+04
# Store_33                  -3.235e+04   1.92e+04     -1.687      0.092   -6.99e+04    5243.930
# Store_34                   3807.5382   1550.624      2.455      0.014     768.359    6846.717
# Store_35                   1.327e+04   6892.249      1.925      0.054    -240.392    2.68e+04
# Store_36                   -3.01e+04   1.64e+04     -1.831      0.067   -6.23e+04    2121.066
# Store_37                  -1.342e+04   6743.364     -1.990      0.047   -2.66e+04    -203.739
# Store_38                  -1.067e+04   7347.637     -1.453      0.146   -2.51e+04    3726.353
# Store_39                   1.572e+04   9763.693      1.610      0.107   -3413.200    3.49e+04
# Store_40                   7795.1222   4480.220      1.740      0.082    -985.985    1.66e+04
# Store_41                   2.071e+04   1.27e+04      1.632      0.103   -4167.072    4.56e+04
# Store_42                  -7312.0302   5037.498     -1.452      0.147   -1.72e+04    2561.326
# Store_43                  -6406.4725   3366.593     -1.903      0.057    -1.3e+04     191.956
# Store_44                  -6567.6037   3891.290     -1.688      0.091   -1.42e+04    1059.217
# Store_45                   2.621e+04   1.55e+04      1.690      0.091   -4181.574    5.66e+04
# Dept_1                    -6303.0392   4426.633     -1.424      0.154    -1.5e+04    2373.037
# Dept_2                    -2623.7522   4357.517     -0.602      0.547   -1.12e+04    5916.861
# Dept_3                    -7402.0343   4287.469     -1.726      0.084   -1.58e+04    1001.285
# Dept_4                    -5090.8554   4218.157     -1.207      0.227   -1.34e+04    3176.616
# Dept_5                    -5197.3564   4148.644     -1.253      0.210   -1.33e+04    2933.870
# Dept_6                    -8062.8553   4078.879     -1.977      0.048   -1.61e+04     -68.367
# Dept_7                    -4212.9095   4009.695     -1.051      0.293   -1.21e+04    3645.982
# Dept_8                    -4017.4532   3940.178     -1.020      0.308   -1.17e+04    3705.185
# Dept_9                    -5372.4384   3870.518     -1.388      0.165    -1.3e+04    2213.669
# Dept_10                   -5538.7586   3800.973     -1.457      0.145    -1.3e+04    1911.043
# Dept_11                   -5981.4647   3731.424     -1.603      0.109   -1.33e+04    1332.022
# Dept_12                   -7508.1624   3661.834     -2.050      0.040   -1.47e+04    -331.069
# Dept_13                   -3409.4121   3592.649     -0.949      0.343   -1.05e+04    3632.080
# Dept_14                   -5414.0478   3522.935     -1.537      0.124   -1.23e+04    1490.807
# Dept_16                   -5631.5487   3383.876     -1.664      0.096   -1.23e+04    1000.754
# Dept_17                   -5931.1104   3314.367     -1.790      0.074   -1.24e+04     564.957
# Dept_18                   -5722.6446   3244.549     -1.764      0.078   -1.21e+04     636.581
# Dept_19                   -7503.9787   3176.066     -2.363      0.018   -1.37e+04   -1278.977
# Dept_20                   -6492.5310   3106.073     -2.090      0.037   -1.26e+04    -404.714
# Dept_21                   -6298.9498   3036.355     -2.075      0.038   -1.23e+04    -347.778
# Dept_22                   -5555.7365   2967.378     -1.872      0.061   -1.14e+04     260.242
# Dept_23                   -3166.7131   2897.727     -1.093      0.274   -8846.177    2512.751
# Dept_24                   -6055.8081   2828.155     -2.141      0.032   -1.16e+04    -512.704
# Dept_25                   -5247.4487   2758.526     -1.902      0.057   -1.07e+04     159.185
# Dept_26                   -5509.2973   2689.068     -2.049      0.040   -1.08e+04    -238.798
# Dept_27                   -6431.3440   2619.855     -2.455      0.014   -1.16e+04   -1296.502
# Dept_28                   -6289.3844   2550.126     -2.466      0.014   -1.13e+04   -1291.208
# Dept_29                   -5621.8830   2481.066     -2.266      0.023   -1.05e+04    -759.063
# Dept_30                   -5813.6288   2411.664     -2.411      0.016   -1.05e+04   -1086.834
# Dept_31                   -5702.8348   2341.780     -2.435      0.015   -1.03e+04   -1113.011
# Dept_32                   -4819.2851   2272.538     -2.121      0.034   -9273.396    -365.174
# Dept_33                   -5016.2784   2203.320     -2.277      0.023   -9334.725    -697.832
# Dept_34                   -3610.6318   2134.056     -1.692      0.091   -7793.322     572.058
# Dept_35                   -5409.4690   2064.651     -2.620      0.009   -9456.127   -1362.811
# Dept_36                   -5416.7729   1995.298     -2.715      0.007   -9327.502   -1506.044
# Dept_37                   -5806.3266   1929.990     -3.008      0.003   -9589.053   -2023.600
# Dept_38                    3890.9755   1857.253      2.095      0.036     250.812    7531.139
# Dept_39                   -6490.1541   4599.835     -1.411      0.158   -1.55e+04    2525.394
# Dept_40                    1764.6081   1718.032      1.027      0.304   -1602.688    5131.904
# Dept_41                   -4802.0920   1648.519     -2.913      0.004   -8033.144   -1571.040
# Dept_42                   -3932.2894   1578.733     -2.491      0.013   -7026.563    -838.016
# Dept_43                   -3842.9331   5411.236     -0.710      0.478   -1.44e+04    6762.939
# Dept_44                   -4049.0042   1440.627     -2.811      0.005   -6872.592   -1225.416
# Dept_45                   -4836.5941   1376.476     -3.514      0.000   -7534.449   -2138.739
# Dept_46                   -1119.0948   1301.921     -0.860      0.390   -3670.823    1432.634
# Dept_47                   -4589.1872   1346.421     -3.408      0.001   -7228.135   -1950.239
# Dept_48                   -4957.6860   1178.960     -4.205      0.000   -7268.414   -2646.958
# Dept_49                   -3272.3527   1097.925     -2.980      0.003   -5424.255   -1120.450
# Dept_50                   -4548.7580   1044.068     -4.357      0.000   -6595.102   -2502.414
# Dept_51                   -3848.2129    968.480     -3.973      0.000   -5746.407   -1950.019
# Dept_52                   -3305.7238    888.073     -3.722      0.000   -5046.322   -1565.125
# Dept_54                   -3748.5885    753.468     -4.975      0.000   -5225.365   -2271.811
# Dept_55                   -1443.7660    683.811     -2.111      0.035   -2784.017    -103.515
# Dept_56                   -2756.1714    615.391     -4.479      0.000   -3962.320   -1550.023
# Dept_58                   -2935.5507    485.500     -6.046      0.000   -3887.117   -1983.985
# Dept_59                   -2646.1656    414.538     -6.383      0.000   -3458.648   -1833.684
# Dept_60                   -2595.3697    352.475     -7.363      0.000   -3286.211   -1904.528
# Dept_65                    4735.8590    746.947      6.340      0.000    3271.864    6199.854
# Dept_67                    -693.8092    216.375     -3.207      0.001   -1117.898    -269.721
# Dept_71                    -895.7882    468.496     -1.912      0.056   -1814.028      22.451
# Dept_72                    7000.1748    533.998     13.109      0.000    5953.553    8046.796
# Dept_74                    1071.6651    667.561      1.605      0.108    -236.736    2380.066
# Dept_77                   -2485.0698   1361.533     -1.825      0.068   -5153.637     183.497
# Dept_78                   -1168.8168   1204.536     -0.970      0.332   -3529.674    1192.041
# Dept_79                    2783.8168   1010.257      2.756      0.006     803.741    4763.893
# Dept_80                    1369.9326   1080.097      1.268      0.205    -747.027    3486.893
# Dept_81                    2032.4860   1148.271      1.770      0.077    -218.094    4283.066
# Dept_82                    2437.4594   1217.322      2.002      0.045      51.542    4823.377
# Dept_83                     348.6834   1287.133      0.271      0.786   -2174.061    2871.427
# Dept_85                     463.7211   1425.437      0.325      0.745   -2330.097    3257.539
# Dept_87                    2386.6279   1563.425      1.527      0.127    -677.642    5450.898
# Dept_90                    7569.0245   1771.190      4.273      0.000    4097.542     1.1e+04
# Dept_91                    5844.6711   1840.525      3.176      0.001    2237.293    9452.049
# Dept_92                    1.219e+04   1910.218      6.380      0.000    8443.451    1.59e+04
# Dept_93                    5039.1715   1979.565      2.546      0.011    1159.279    8919.064
# Dept_94                    6350.0211   2049.435      3.098      0.002    2333.186    1.04e+04
# Dept_95                    1.171e+04   2118.263      5.529      0.000    7560.937    1.59e+04
# Dept_96                    3885.4647   2188.449      1.775      0.076    -403.834    8174.763
# Dept_97                    3656.9285   2257.121      1.620      0.105    -766.965    8080.822
# Dept_98                    2630.8943   2327.097      1.131      0.258   -1930.152    7191.940
# Dept_99                    -410.6910   2437.375     -0.168      0.866   -5187.879    4366.497
# Type_A                    -4.869e+04   2.71e+04     -1.798      0.072   -1.02e+05    4376.103
# Type_B                    -7.268e+04    4.1e+04     -1.771      0.077   -1.53e+05    7753.127
# Type_C                    -6.403e+04   3.62e+04     -1.767      0.077   -1.35e+05    6991.624
# Week_Number_1             -1.651e+04   9375.983     -1.760      0.078   -3.49e+04    1870.794
# Week_Number_2              -1.57e+04   8347.986     -1.881      0.060   -3.21e+04     661.720
# Week_Number_3             -1.325e+04   7301.384     -1.815      0.070   -2.76e+04    1057.589
# Week_Number_4             -1.174e+04   6256.295     -1.877      0.061    -2.4e+04     518.302
# Week_Number_5             -7310.9353   5212.558     -1.403      0.161   -1.75e+04    2905.532
# Week_Number_6              -1.04e+04   6441.277     -1.614      0.106    -2.3e+04    2226.025
# Week_Number_7             -5188.8744   3088.155     -1.680      0.093   -1.12e+04     863.823
# Week_Number_8             -5018.4329   2043.784     -2.455      0.014   -9024.194   -1012.672
# Week_Number_9              -833.3990    991.583     -0.840      0.401   -2776.873    1110.075
# Week_Number_10             -350.8616    131.103     -2.676      0.007    -607.820     -93.903
# Week_Number_11             1864.9581   1120.294      1.665      0.096    -330.786    4060.703
# Week_Number_12             3338.1533   2159.969      1.545      0.122    -895.326    7571.633
# Week_Number_13            -1.579e+04   9496.565     -1.663      0.096   -3.44e+04    2822.149
# Week_Number_14            -1.504e+04   8447.797     -1.780      0.075   -3.16e+04    1518.039
# Week_Number_15            -1.359e+04   7398.580     -1.837      0.066   -2.81e+04     909.447
# Week_Number_16            -1.072e+04   6353.349     -1.687      0.092   -2.32e+04    1735.814
# Week_Number_17            -1.039e+04   5308.416     -1.957      0.050   -2.08e+04      14.728
# Week_Number_18            -6217.3140   4259.971     -1.459      0.144   -1.46e+04    2132.112
# Week_Number_19            -6335.3293   3216.604     -1.970      0.049   -1.26e+04     -30.874
# Week_Number_20            -4078.5586   2176.673     -1.874      0.061   -8344.776     187.659
# Week_Number_21            -1380.0670   1144.324     -1.206      0.228   -3622.909     862.775
# Week_Number_22             4453.8722   2145.217      2.076      0.038     249.307    8658.438
# Week_Number_23             4830.3561   3183.669      1.517      0.129   -1409.547    1.11e+04
# Week_Number_24             7119.5979   4222.556      1.686      0.092   -1156.495    1.54e+04
# Week_Number_25             8580.1647   5263.841      1.630      0.103   -1736.818    1.89e+04
# Week_Number_26            -2.399e+04   1.38e+04     -1.734      0.083   -5.11e+04    3121.975
# Week_Number_27            -2.286e+04   1.28e+04     -1.787      0.074   -4.79e+04    2210.853
# Week_Number_28            -2.158e+04   1.17e+04     -1.837      0.066   -4.46e+04    1448.131
# Week_Number_29            -1.941e+04   1.07e+04     -1.813      0.070   -4.04e+04    1570.933
# Week_Number_30            -1.762e+04   9660.772     -1.824      0.068   -3.66e+04    1314.319
# Week_Number_31            -1.412e+04   8617.053     -1.639      0.101    -3.1e+04    2764.573
# Week_Number_32            -1.404e+04   7574.677     -1.854      0.064   -2.89e+04     804.794
# Week_Number_33            -1.146e+04   6536.870     -1.753      0.080   -2.43e+04    1354.591
# Week_Number_34            -9912.2284   5497.684     -1.803      0.071   -2.07e+04     863.079
# Week_Number_35            -8092.5469   4456.308     -1.816      0.069   -1.68e+04     641.693
# Week_Number_36            -9279.1764   5723.983     -1.621      0.105   -2.05e+04    1939.671
# Week_Number_37            -5201.2292   2372.054     -2.193      0.028   -9850.389    -552.069
# Week_Number_38            -3024.4158   1334.099     -2.267      0.023   -5639.213    -409.619
# Week_Number_39             -939.1343    301.847     -3.111      0.002   -1530.745    -347.523
# Week_Number_40             1971.8715    772.107      2.554      0.011     458.563    3485.180
# Week_Number_41             1861.9264   1810.308      1.029      0.304   -1686.227    5410.080
# Week_Number_42             4676.0057   2854.664      1.638      0.101    -919.055    1.03e+04
# Week_Number_43             6442.5760   3896.411      1.653      0.098   -1194.280    1.41e+04
# Week_Number_44             9089.5757   4936.813      1.841      0.066    -586.440    1.88e+04
# Week_Number_45             1.012e+04   5985.599      1.691      0.091   -1612.203    2.19e+04
# Week_Number_46             1.154e+04   7028.040      1.642      0.101   -2235.153    2.53e+04
# Week_Number_47             1.637e+04   5757.791      2.843      0.004    5086.354    2.77e+04
# Week_Number_48             8122.9447   6863.263      1.184      0.237   -5328.860    2.16e+04
# Week_Number_49             1.636e+04   7903.359      2.070      0.038     867.035    3.18e+04
# Week_Number_50             1.821e+04   8943.819      2.036      0.042     677.774    3.57e+04
# Week_Number_51             2.458e+04   9984.256      2.462      0.014    5011.711    4.41e+04
# Week_Number_52             6454.4560   8725.656      0.740      0.459   -1.06e+04    2.36e+04
# MarkDown                      0.0326      0.012      2.826      0.005       0.010       0.055
# Weekly_Sales_Lag              0.8555      0.001    806.915      0.000       0.853       0.858
# MarkDown:Weekly_Sales_Lag -3.052e-06   3.69e-08    -82.668      0.000   -3.12e-06   -2.98e-06
# ==============================================================================
# Omnibus:                   448685.643   Durbin-Watson:                   2.539
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      10881675054.079
# Skew:                           8.490   Prob(JB):                         0.00
# Kurtosis:                     952.972   Cond. No.                     1.54e+23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is  3e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# Exploratory Analysis and descriptive statistics
#
# In this step we are trying to analyze which particular departments contribute to higher sales and thus would play a pivotal role in predicting the sales in future weeks

# %%
unique_dept_values = master_df_new_var.Dept.unique() #getting unique values of store by department type
unique_data_string = []    #creating null list
mark = []

#creating unique list containing names of department for creating labels for the graph
for counter in range(0, len(unique_dept_values)):
    if unique_dept_values[counter] == 38 or unique_dept_values[counter] == 92 or unique_dept_values[counter] == 95:
        unique_data_string.append("Dept-" + str(unique_dept_values[counter]))
        mark.append("+")
    else:
        unique_data_string.append("")
        mark.append("o")


mean_sales = []   #creating list of mean sales
for intcounter in unique_dept_values:
    mean_sales.append(data_train[data_train["Dept_" + str(intcounter)]==1]["Weekly_Sales"].mean()) #estimating mean sales for store by department type

#creating formula for regression
equals_to_str_dept = "Weekly_Sales ~ Weekly_Sales_Lag + isHoliday + Temperature + Type_A + Type_B + Type_C+ Week_Number_50 + Week_Number_51 + " 
for intcounter in range(len(unique_dept_values)):
    if intcounter != len(unique_dept_values)-1:
        equals_to_str_dept = equals_to_str_dept + "Dept_" + str(unique_dept_values[intcounter]) + " + "
    else:
        equals_to_str_dept = equals_to_str_dept + "Dept_" + str(unique_dept_values[intcounter])

#running regression with relevant variables and all the department type to calculate which department type impacts the weekly sales the most
result_with_dpt = sm.ols(formula=equals_to_str_dept, data = data_train).fit()
result_list = result_with_dpt.tvalues #calculating t value to zero in on important parameters
result_tstat = []
 
for intcounter in range(9,90):
    result_tstat.append(result_list[intcounter]) #getting t stat value for each department and store type
 
fig, ax = plt.subplots()
ax.scatter(result_tstat, mean_sales) #making a scatter plot to highlight high performing departments
plt.xlabel('T- statistics')
plt.ylabel('Mean Weekly Sales')
plt.title('Mean weekly sales by department type')

for i, txt in enumerate(unique_data_string):
    ax.annotate(txt, (result_tstat[i],mean_sales[i])) #identifying the high performing graph and labelling them

# %% [markdown]
# The graph here illustrates Department 38, 95 and 92 performing extra-ordinarily in terms of mean weekly sales. T-statistics are the values obtained by keeping all the departments as an independent variable in the full model and then observing the significance of these varibles in getting to the response variable (future weekly sale)
#
#
# We have found out the next set of important variables. They include size, markdown and yearly lag.

# %%
ax= sns.barplot(x="Store", y="Weekly_Sales",  data=master_df_new_var)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=7)
plt.tight_layout()
plt.show()

# %% [markdown]
# The above graph shows the relative variation in average weekly sales for different stores in Walmart

# %%
sns.barplot(x="Year", y="Weekly_Sales", hue="Type", data=master_df)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Weekly_Sales'>

# %% [markdown]
# In the above chart we can see the variation in the average sales of type A, type B, and type C stores. Type A store have the highest average sales.

# %%
df_corr = master_df.corr()
ax=df_corr[['Weekly_Sales']].plot(kind='bar')
plt.xlabel('Attribute')
plt.ylabel('Correlation')
plt.title('Correlation of Weekly sales with other variables')
plt.tight_layout()
plt.show()

# %% [markdown]
# From the above correlation matrix we can see that many factors in the original dataset had week correlation with weekly sales. Therefore, to better explain the weekly sales we have identified new variables like weekly lag and yearly lag which provides a robust time series trend analysis for the future sales.

# %%
heat_df= master_df[['Store','Dept','Weekly_Sales']]
heat_map=heat_df.groupby(['Store','Dept']).mean()
heat_map.reset_index(inplace=True)
heat_map=heat_map.pivot('Store','Dept','Weekly_Sales')
fig, ax = plt.subplots(figsize=(20,7))
sns.heatmap(heat_map, cmap="YlGnBu", ax=ax)
plt.xlabel('Department')
plt.ylabel('Store')
plt.title('A heatmap indicating average sales of various departments')
plt.tight_layout()
plt.show()

# %% [markdown]
# The above heatmap helped us in augmenting our decision of including critical departments like 92, 95, and 38 in our regression equation

# %%
#function to draw pair plot
def drawpairplot(total_clusters, data, blnDraw):
    kmeans=KMeans(n_clusters=total_clusters).fit(data)
    data['Cluster']=kmeans.labels_
    if blnDraw:
        sns.pairplot(data,hue='Cluster')

df = copy.deepcopy(master_df)   #creating a copy of the data frame to not change the master data frame
df["Type"] = df['Type'].map({'A': int(0), 'B': int(1), 'C': int(2)}) #giving numberical values to different store types

nClusters = range(2,7)  #defining a range of clusters between 2 and 7
rel_cols=['Type', 'Weekly_Sales'] #defining the relevant columns in the data set on which clustering needs to run

sumDistances=[]

#calculating SSE
for n in nClusters:
    kmeans=KMeans(n_clusters=n).fit(df[rel_cols])
    sumDistances.append(kmeans.inertia_) #Proxy for SSE

# Plotting the elbow graph
plt.plot(nClusters,sumDistances,'-')
plt.xlabel('nClusters')
plt.ylabel('Sum Of Distances')
plt.show()

# %%
print("As we see a slight kink at cluster = 3. Assuming cluster as 3 and plotting the pair plot")
drawpairplot(3,df[rel_cols],True) #drawing pair plot for 3 clusters
# Out:
# As we see a slight kink at cluster = 3. Assuming cluster as 3 and plotting the pair plot
# /var/folders/81/8tq9rszx7vs5py4pq8yqqsdc0000gn/T/ipykernel_6530/1559137413.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Cluster']=kmeans.labels_

# %% [markdown]
# Hence we can see that 3rd cluster which corresponds to "Type A" stores, have the most weekly sales and may be the largest store type amongst the other two stores. The classification of the masked data in the "Type" column of the dataset might indicate the size of the store.

# %% [markdown]
# Variable Shortlisting based on above analysis

# %%
features = ['isHoliday', 'Temperature', 'Weekly_Sales_Lag']#, 'Size', 'MarkDown5', 'master_df_new_var']
features.extend(master_df_new_var.columns[master_df_new_var.columns.str.startswith('Type')])
features.remove('Type')

# %%
equals_to_str = ""

for i in features:
    equals_to_str = equals_to_str + str(i) + " + "

equals_to_str = str('Weekly_Sales ~ ') + equals_to_str
equals_to_str = equals_to_str  + 'Week_Number_50 + Week_Number_51+ Dept_95 + Dept_92+ Dept_38'
equals_to_str_withpromotion = equals_to_str  + '+ MarkDown*Weekly_Sales_Lag'

# %% [markdown]
# Reduced Models

# %%
result_withoutpromotion = sm.ols(formula=equals_to_str, data = data_train).fit()
print("Model 1 without Promotion \n",result_withoutpromotion.summary())
# Out:
# Model 1 without Promotion
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           Weekly_Sales   R-squared:                       0.879
# Model:                            OLS   Adj. R-squared:                  0.879
# Method:                 Least Squares   F-statistic:                 2.099e+05
# Date:                Wed, 16 Nov 2022   Prob (F-statistic):               0.00
# Time:                        20:13:06   Log-Likelihood:            -3.0104e+06
# No. Observations:              289299   AIC:                         6.021e+06
# Df Residuals:                  289288   BIC:                         6.021e+06
# Df Model:                          10
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept           247.3962     42.690      5.795      0.000     163.725     331.067
# isHoliday[T.True]  -845.5337     55.780    -15.158      0.000    -954.860    -736.207
# Temperature           9.9790      0.837     11.928      0.000       8.339      11.619
# Weekly_Sales_Lag      0.9067      0.001   1185.741      0.000       0.905       0.908
# Type_A              698.9296     24.786     28.199      0.000     650.351     747.509
# Type_B                5.6130     24.101      0.233      0.816     -41.624      52.850
# Type_C             -457.1464     40.400    -11.316      0.000    -536.328    -377.964
# Week_Number_50     2363.1381    106.518     22.185      0.000    2154.366    2571.911
# Week_Number_51     6783.5677    106.467     63.715      0.000    6574.895    6992.240
# Dept_95            5074.3453    128.151     39.597      0.000    4823.173    5325.518
# Dept_92            5462.1660    129.366     42.223      0.000    5208.612    5715.720
# Dept_38            4289.9392    126.057     34.032      0.000    4042.872    4537.007
# ==============================================================================
# Omnibus:                   322653.403   Durbin-Watson:                   2.644
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       8837920688.651
# Skew:                           4.081   Prob(JB):                         0.00
# Kurtosis:                     859.224   Cond. No.                     5.09e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.87e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
result_withpromotion = sm.ols(formula=equals_to_str_withpromotion, data = data_train).fit()
print("Model 1 with Promotion \n",result_withpromotion.summary())
# Out:
# Model 1 with Promotion
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           Weekly_Sales   R-squared:                       0.883
# Model:                            OLS   Adj. R-squared:                  0.883
# Method:                 Least Squares   F-statistic:                 1.822e+05
# Date:                Wed, 16 Nov 2022   Prob (F-statistic):               0.00
# Time:                        20:13:19   Log-Likelihood:            -3.0052e+06
# No. Observations:              289299   AIC:                         6.010e+06
# Df Residuals:                  289286   BIC:                         6.010e+06
# Df Model:                          12
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    37.1945     42.183      0.882      0.378     -45.482     119.872
# isHoliday[T.True]          -852.3239     57.564    -14.806      0.000    -965.148    -739.500
# Temperature                   9.8274      0.826     11.902      0.000       8.209      11.446
# Weekly_Sales_Lag              0.9295      0.001   1186.239      0.000       0.928       0.931
# Type_A                      523.3284     24.537     21.328      0.000     475.236     571.421
# Type_B                      -72.7195     23.749     -3.062      0.002    -119.267     -26.172
# Type_C                     -413.4144     39.680    -10.419      0.000    -491.187    -335.642
# Week_Number_50             2256.6944    104.664     21.561      0.000    2051.556    2461.832
# Week_Number_51             6673.0064    104.573     63.812      0.000    6468.046    6877.967
# Dept_95                    4280.9141    126.114     33.945      0.000    4033.733    4528.095
# Dept_92                    4809.7483    127.235     37.802      0.000    4560.371    5059.125
# Dept_38                    3575.8496    124.011     28.835      0.000    3332.792    3818.907
# MarkDown                      0.0938      0.002     52.599      0.000       0.090       0.097
# MarkDown:Weekly_Sales_Lag -3.881e-06   3.77e-08   -102.926      0.000   -3.95e-06   -3.81e-06
# ==============================================================================
# Omnibus:                   403272.909   Durbin-Watson:                   2.609
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      10351804946.193
# Skew:                           6.666   Prob(JB):                         0.00
# Kurtosis:                     929.606   Cond. No.                     9.24e+23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.35e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
data_test = pd.concat([data_test, result_withoutpromotion.predict(data_test).rename("predicted_values_withoutpromotion")], axis=1)
print('The accuracy of the model is', round((1-(metrics.median_absolute_error(data_test.predicted_values_withoutpromotion, data_test.Weekly_Sales)/data_test.Weekly_Sales.median()))*100, 2), '%.(in the test dataset)')
data_train = pd.concat([data_train, result_withoutpromotion.predict(data_train).rename("predicted_values_withoutpromotion")], axis=1)
print('The accuracy of the model is', round((1-(metrics.median_absolute_error(data_train.predicted_values_withoutpromotion, data_train.Weekly_Sales)/data_train.Weekly_Sales.median()))*100, 2), '%.(in the train dataset)')
# Out:
# The accuracy of the model is 84.56 %.(in the test dataset)
# The accuracy of the model is 84.53 %.(in the train dataset)

# %%
pred_val = result_withoutpromotion.fittedvalues.copy()
true_val = data_train['Weekly_Sales'].values.copy()
residual = true_val - pred_val
fig, ax = plt.subplots(figsize=(15,5))
plt.xlabel('Error in Predicted Value', fontsize = 18)
plt.ylabel('Predicted Value', fontsize = 18)
plt.title("Residual plot (for Train Data)", fontsize = 20)
_ = ax.scatter(pred_val, residual)

# %% [markdown]
# From the above residual plot for the train data we can see that the errors are farely random and we do not see any clear pattern among the residuals. Therefore, we can say that our linear regression does not have any heteroscedasticity

# %%
fig, ax = plt.subplots(figsize=(15,5))
_, (__, ___, r) = sp.stats.probplot(residual, plot=ax, fit=True)
#r**2

# %% [markdown]
# The above probability plot indicates that the residuals are normally distributed.

# %%
pred_val = result_withpromotion.fittedvalues.copy()
true_val = data_train['Weekly_Sales'].values.copy()
residual = true_val - pred_val
fig, ax = plt.subplots(figsize=(15,5))
plt.xlabel('Error in Predicted Value', fontsize = 18)
plt.ylabel('Predicted Value', fontsize = 18)
plt.title("Comparison of Predicted Values VS Error (for Test Data)", fontsize = 20)
_ = ax.scatter(pred_val, residual)

# %% [markdown]
# From the above residual plot for the test data we can see that the errors are fairly random and we do not see any clear pattern among the residuals. Therefore, we can say that our linear regression does not have any heteroscedasticity

# %%
fig, ax = plt.subplots(figsize=(15,5))
_, (__, ___, r) = sp.stats.probplot(residual, plot=ax, fit=True)
#r**2

# %% [markdown]
# The above probability plot indicates that the residuals are normally distributed

# %%
data_test["predicted_values_withoutpromotion"] = result_withoutpromotion.predict(data_test)
data_test["predicted_values_withpromotion"] = result_withoutpromotion.predict(data_test)

actual_sales = data_test.groupby("Dept").mean()["Weekly_Sales"]
predicted_sales_withoutpromotion = data_test.groupby("Dept").mean()["predicted_values_withoutpromotion"]
#data_test.to_csv("predictedvsactual.csv")

# %%
plt.scatter(data_test['Weekly_Sales'], data_test['predicted_values_withpromotion'])
plt.xlabel('Actual Value', fontsize = 18)
plt.ylabel('Predicted Value', fontsize = 18)
plt.title("Scatter plot of Actual Value VS Predicted Value", fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Scatter plot of Actual Value VS Predicted Value')

# %% [markdown]
# Scalability Analysis
#
# Modifying the regression for scalability purposes

# %%
# To calculate L2 norm
def normDiff (x, y, ord=2): 
    return np.linalg.norm (x - y, ord=ord) / np.linalg.norm (y, ord=ord) #Normalized by the "length" of y.

# %% [markdown]
# Please note that even though the batchwise regression is currently run on data points, the code to run it on a batch is mentioned in the commented portions.

# %%
# Define batchwise regression
def run_ols_batchwise(DataFrame, Formula):
    df_length = len(DataFrame.index)
    
    # Getting an initial estimate for beta coefficients
    DataFrame.index = range(df_length)
    DataFrame['batch_number'] = DataFrame.index % int(df_length/10000)
    result = sm.ols(Formula, DataFrame.loc[DataFrame.batch_number == 1]).fit()
    
    # Extracting relevant columns out of formula
    variables = Formula.split('+')
    variable1 = variables[0].split('~')[1]
    variables.remove(variables[0])
    variables.insert(0, variable1)
    variables.insert(0, 'Constant')
    variables = [x.strip(' ') for x in variables]

    # Preparing the data for interative linear regression
    DataFrame['Constant'] = 1
    X = np.array(DataFrame[variables])
    y = np.array(DataFrame.Weekly_Sales)
    beta_t = np.array(result.params)
    phi = 2/max(result.eigenvals)
    
    for t in range(int(df_length)):
        
        #print("Iteration1:", beta_t)
        #y_data_array = DataFrame[(100*t):(100*(t + 1))]['Weekly_Sales']
        #x_data_array = DataFrame.loc[(100*t):(100*(t + 1))-1, variables]
        #yT = np.array(y_data_array)
        #xT = np.array(x_data_array)
        
        xT = X[t,:]
        yT = y[t]
        
        #print(xT.shape)
        #print(yT.shape)
        #print(beta_t.shape)
        
        #delta_t = phi * xT.T.dot(yT -xT.dot(beta_t))
        
        delta_t = phi * xT.dot(yT -xT.T.dot(beta_t))
        
        beta_t = beta_t + delta_t
    
    return beta_t

# %%
# Function calling
batchwise_beta = run_ols_batchwise(data_test, equals_to_str)
print('The mean error (MSE) in predicting the coeficient is ', round(normDiff(batchwise_beta, result_withoutpromotion.params), 4)*100, '%')
# Out:
# The mean error (MSE) in predicting the coeficient is  85.76 %

# %% [markdown]
# Time complexity analysis

# %%
# To measure the time taken to execute the function
def measureTime(fun,arg1):
    nTimes=10
    times=np.zeros(nTimes)
    for i in range(nTimes):
        startTime = time.time()    
        fun(arg1)
        endTime = time.time()
        times[i]=endTime-startTime
    return np.mean(times)

# %%
# We use the model to predict the expected sales
def predict(total_obs):
    X = []
    y = []
    for obs in range(total_obs):
        i=random.randint(0, len(data_test))
        x=pd.DataFrame(data_test.iloc[i,:]).T[["isHoliday", "Temperature", "Weekly_Sales_Lag", "Type_A", "Type_B", "Type_C", "Week_Number_50", "Week_Number_51", "Dept_95", "Dept_92", "Dept_38"]]
        x=x.astype(int)
        X.append(x)
        predicted_value = result_withoutpromotion.predict(x)
        y.append(predicted_value)
    return (X, y)

# %%
N = 11                                                   # Number of variables is set constant
M = np.geomspace(start=15,stop=1000,num=5,dtype=int)    # Varying the number of observations

times = np.zeros(len(M))
for (i, m) in enumerate(M):
    t = measureTime(predict, m)
    times[i] = t

# %%
# Creating Benchmarks
linearTime = [times[0]/M[0]*m for m in M]
lognTime = [times[0]/(np.log(M[0]))*(np.log(m)) for m in M]
nlognTime = [times[0]/(M[0]*np.log(M[0]))*(m*np.log(m)) for m in M]
loglognTime = [times[0]/(np.log(M[0])*np.log(M[0]))*(np.log(m)*np.log(m)) for m in M]

# Plotting the result
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.loglog (M, times, 'k-',linewidth=3,label="Code")

ax1.loglog (M, linearTime, 'b--',label="Linear")
ax1.loglog (M, lognTime, 'g--',label="Log(m)")
ax1.loglog (M, nlognTime, 'r--',label="m*Log(m)")

plt.xlabel('Number of Independent Variables')
plt.ylabel('Time (Seconds)')
plt.title("Comparison of Time plot with linear, log(n), and n*log(n) plots")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
profile.run('print(predict(20));print(\'=\' * 100)')
# Out:
# ([       isHoliday  Temperature  Weekly_Sales_Lag  Type_A  Type_B  Type_C  \
# 10155          0           80             15486       1       0       0
#
#        Week_Number_50  Week_Number_51  Dept_95  Dept_92  Dept_38
# 10155               0               0        0        0        0  ,        isHoliday  Temperature  Weekly_Sales_Lag  Type_A  Type_B  Type_C  \
# 37977          0           32            125132       1       0       0
#
#        Week_Number_50  Week_Number_51  Dept_95  Dept_92  Dept_38
# 37977               0               0        0        0        0  ,       isHoliday  Temperature  Weekly_Sales_Lag  Type_A  Type_B  Type_C  \
# 2981          0           84             33754       1       0       0
#
#       Week_Number_50  Week_Number_51  Dept_95  Dept_92  Dept_38
# 2981               0               0        0        0        0  ,        isHoliday  Temperature  Weekly_Sales_Lag  Type_A  Type_B  Type_C  \
# 48033          0           46              4574       0       1       0
#
#        Week_Number_50  Week_Number_51  Dept_95  Dept_92  Dept_38
# 48033               0               0        0        0        0  ,        isHoliday  Temperature  Weekly_Sales_Lag  Type_A  Type_B  Type_C  \
# 68477          0           71             31793       1       0       0
#
#        Week_Number_50  Week_Number_51  Dept_95  Dept_92  Dept_38
# 68477               0               0        0        0        0  ,        isHoliday  Temperature  Weekly_Sales_Lag  Type_A  Type_B  Type_C  \
# 60302          0           70             13329       0       1       0
#
#        Week_Number_50  Week_Number_51  Dept_95  Dept_92  Dept_38
# 60302               0               0        0        0        0  ,       isHoliday  Temperature  Weekly_Sales_Lag  Type_A  Type_B  Type_C  \
# 8511          0           58              1224       0       1       0
#
#       Week_Number_50  Week_Number_51  Dept_95  Dept_92  Dept_38
# 8511               0               0        0        0        0  ,         isHoliday  Temperature  Weekly_Sales_Lag  Type_A  Type_B  Type_C  \
# 126114          0           54               697       0       1       0
#
#         Week_Number_50  Week_Number_51  Dept_95  Dept_92  Dept_38
# 126114               0               0        0        0        0  ,        isHoliday  Temperature  Weekly_Sales_Lag  Type_A  Type_B  Type_C  \
# 84608          0           66               805       0       1       0
#
#        Week_Number_50  Week_Number_51  Dept_95  Dept_92  Dept_38
# 84608               0               0        0        0        0  ,        isHoliday  Temperature  Weekly_Sales_Lag  Type_A  Type_B  Type_C  \
# 38380          0           81                90       1       0       0
#
#        Week_Number_50  Week_Number_51  Dept_95  Dept_92  Dept_38
# 38380               0               0        0        0        0  ,        isHoliday  Temperature  Weekly_Sales_Lag  Type_A  Type_B  Type_C  \
# 25169          0           69             33330       0       1       0
#
#        Week_Number_50  Week_Number_51  Dept_95  Dept_92  Dept_38
# 25169               0               0        0        0        0  ,        isHoliday  Temperature  Weekly_Sales_Lag  Type_A  Type_B  Type_C  \
# 73096          1           32               875       0       1       0
#
#        Week_Number_50  Week_Number_51  Dept_95  Dept_92  Dept_38
# 73096               0               0        0        0        0  ,        isHoliday  Temperature  Weekly_Sales_Lag  Type_A  Type_B  Type_C  \
# 72969          0           58              2267       0       1       0
#
#        Week_Number_50  Week_Number_51  Dept_95  Dept_92  Dept_38
# 72969               0               0        0        0        0  ,        isHoliday  Temperature  Weekly_Sales_Lag  Type_A  Type_B  Type_C  \
# 11156          0           80             82105       1       0       0
#
#        Week_Number_50  Week_Number_51  Dept_95  Dept_92  Dept_38
# 11156               0               0        0        0        0  ,        isHoliday  Temperature  Weekly_Sales_Lag  Type_A  Type_B  Type_C  \
# 96964          0           59              5835       1       0       0
#
#        Week_Number_50  Week_Number_51  Dept_95  Dept_92  Dept_38
# 96964               0               0        0        0        0  ,        isHoliday  Temperature  Weekly_Sales_Lag  Type_A  Type_B  Type_C  \
# 65721          0           28             25026       0       1       0
#
#        Week_Number_50  Week_Number_51  Dept_95  Dept_92  Dept_38
# 65721               0               0        0        0        0  ,        isHoliday  Temperature  Weekly_Sales_Lag  Type_A  Type_B  Type_C  \
# 42751          0           49              4952       0       1       0
#
#        Week_Number_50  Week_Number_51  Dept_95  Dept_92  Dept_38
# 42751               0               0        0        0        0  ,        isHoliday  Temperature  Weekly_Sales_Lag  Type_A  Type_B  Type_C  \
# 34872          1           52             15108       0       1       0
#
#        Week_Number_50  Week_Number_51  Dept_95  Dept_92  Dept_38
# 34872               0               0        0        0        0  ,         isHoliday  Temperature  Weekly_Sales_Lag  Type_A  Type_B  Type_C  \
# 110393          0           60               364       1       0       0
#
#         Week_Number_50  Week_Number_51  Dept_95  Dept_92  Dept_38
# 110393               0               0        0        0        0  ,       isHoliday  Temperature  Weekly_Sales_Lag  Type_A  Type_B  Type_C  \
# 5069          0           70              8645       1       0       0
#
#       Week_Number_50  Week_Number_51  Dept_95  Dept_92  Dept_38
# 5069               0               0        0        0        0  ], [10155    15785.543991
# dtype: float64, 37977    114720.776537
# dtype: float64, 2981    32388.754627
# dtype: float64, 48033    4859.211994
# dtype: float64, 68477    30481.021716
# dtype: float64, 60302    13036.72141
# dtype: float64, 8511    1941.569698
# dtype: float64, 126114    1423.831629
# dtype: float64, 84608    1641.500991
# dtype: float64, 38380    1836.223272
# dtype: float64, 25169    31161.319801
# dtype: float64, 73096    520.150396
# dtype: float64, 72969    2887.240623
# dtype: float64, 11156    76187.894306
# dtype: float64, 96964    6825.583014
# dtype: float64, 65721    23223.082309
# dtype: float64, 42751    5231.875255
# dtype: float64, 34872    13624.556361
# dtype: float64, 110393    1875.096365
# dtype: float64, 5069    9483.132322
# dtype: float64])
# ====================================================================================================
#          663488 function calls (653088 primitive calls) in 1.311 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.001    0.001    1.091    1.091 2983308015.py:2(predict)
#         4    0.000    0.000    0.000    0.000 :0(__exit__)
#       560    0.001    0.000    0.001    0.000 :0(__new__)
#       480    0.001    0.000    0.001    0.000 :0(_abc_instancecheck)
#        20    0.000    0.000    0.000    0.000 :0(_abc_subclasscheck)
#       320    0.000    0.000    0.000    0.000 :0(_filters_mutated)
#        20    0.000    0.000    0.000    0.000 :0(_getframe)
#        60    0.000    0.000    0.001    0.000 :0(_rebuild_blknos_and_blklocs)
#        20    0.000    0.000    0.000    0.000 :0(_set_freq)
#        20    0.000    0.000    0.000    0.000 :0(_simple_new)
#         1    0.000    0.000    0.000    0.000 :0(acquire)
#      2481    0.006    0.000    0.022    0.000 :0(all)
#      1340    0.004    0.000    0.012    0.000 :0(any)
#      6761    0.006    0.000    0.006    0.000 :0(append)
#        20    0.000    0.000    0.000    0.000 :0(argsort)
#      5380    0.007    0.000    0.007    0.000 :0(array)
#        20    0.000    0.000    0.000    0.000 :0(array_to_datetime)
#      4480    0.003    0.000    0.003    0.000 :0(asanyarray)
# 2720/2260    0.005    0.000    0.017    0.000 :0(asarray)
#      1360    0.002    0.000    0.002    0.000 :0(astype)
#        20    0.000    0.000    0.000    0.000 :0(astype_intsafe)
#        20    0.000    0.000    0.000    0.000 :0(bit_length)
#       960    0.001    0.000    0.001    0.000 :0(callable)
#        40    0.000    0.000    0.000    0.000 :0(checknull)
#       400    0.000    0.000    0.000    0.000 :0(clear)
#       220    0.002    0.000    0.002    0.000 :0(compile)
#       200    0.000    0.000    0.000    0.000 :0(copy)
#        20    0.000    0.000    0.000    0.000 :0(datetime_data)
#        20    0.000    0.000    0.000    0.000 :0(dtypes_all_equal)
#      1020    0.003    0.000    0.003    0.000 :0(empty)
#        40    0.000    0.000    0.000    0.000 :0(encode)
#        41    0.000    0.000    0.000    0.000 :0(endswith)
#      4400    0.004    0.000    0.004    0.000 :0(ensure_object)
#       160    0.000    0.000    0.000    0.000 :0(ensure_platform_int)
#        20    0.000    0.000    0.000    0.000 :0(eq)
#       220    0.000    0.000    0.026    0.000 :0(eval)
#         1    0.000    0.000    1.311    1.311 :0(exec)
#       560    0.001    0.000    0.001    0.000 :0(extend)
#        20    0.000    0.000    0.000    0.000 :0(fileno)
#       320    0.000    0.000    0.000    0.000 :0(format)
#        20    0.000    0.000    0.000    0.000 :0(fromkeys)
#      1680    0.002    0.000    0.003    0.000 :0(get)
#        20    0.000    0.000    0.000    0.000 :0(get_blkno_placements)
#        40    0.000    0.000    0.000    0.000 :0(get_indexer)
#       220    0.000    0.000    0.000    0.000 :0(get_loc)
#        20    0.000    0.000    0.000    0.000 :0(get_terminal_size)
# 22500/22460    0.020    0.000    0.023    0.000 :0(getattr)
#       960    0.001    0.000    0.001    0.000 :0(geterrobj)
#         4    0.000    0.000    0.000    0.000 :0(getpid)
#        21    0.000    0.000    0.000    0.000 :0(getrandbits)
#        20    0.000    0.000    0.000    0.000 :0(getvalue)
#      6460    0.009    0.000    0.010    0.000 :0(hasattr)
#      6320    0.005    0.000    0.005    0.000 :0(hash)
#   880/840    0.003    0.000    0.107    0.000 :0(implement_array_function)
#      4380    0.006    0.000    0.006    0.000 :0(infer_datetimelike_array)
#        80    0.001    0.000    0.001    0.000 :0(infer_dtype)
#       140    0.000    0.000    0.000    0.000 :0(insert)
#        20    0.000    0.000    0.000    0.000 :0(invert)
#        20    0.000    0.000    0.000    0.000 :0(is_all_arraylike)
#       400    0.000    0.000    0.000    0.000 :0(is_bool)
#        20    0.000    0.000    0.000    0.000 :0(is_bool_list)
#        20    0.000    0.000    0.000    0.000 :0(is_datetime_array)
#      1780    0.001    0.000    0.001    0.000 :0(is_float)
#        20    0.000    0.000    0.000    0.000 :0(is_float_nan)
#      2800    0.002    0.000    0.002    0.000 :0(is_integer)
#      1260    0.001    0.000    0.001    0.000 :0(is_iterator)
#      4180    0.005    0.000    0.005    0.000 :0(is_list_like)
#      1480    0.002    0.000    0.002    0.000 :0(is_scalar)
#    132408    0.134    0.000    0.176    0.000 :0(isinstance)
#     20380    0.016    0.000    0.016    0.000 :0(issubclass)
#      1560    0.002    0.000    0.002    0.000 :0(item_from_zerodim)
#       480    0.000    0.000    0.000    0.000 :0(items)
#       620    0.001    0.000    0.001    0.000 :0(iter)
#       240    0.000    0.000    0.000    0.000 :0(join)
#       240    0.000    0.000    0.000    0.000 :0(keys)
# 45565/36885    0.048    0.000    0.062    0.000 :0(len)
#       680    0.001    0.000    0.001    0.000 :0(ljust)
#        20    0.000    0.000    0.000    0.000 :0(lower)
#       200    0.000    0.000    0.000    0.000 :0(lstrip)
#        42    0.000    0.000    0.000    0.000 :0(match)
#      2160    0.004    0.000    0.010    0.000 :0(max)
#       400    0.004    0.000    0.009    0.000 :0(maybe_convert_objects)
#       640    0.002    0.000    0.133    0.000 :0(maybe_dispatch_ufunc_to_dunder_op)
#        20    0.000    0.000    0.000    0.000 :0(maybe_get_tz)
#        40    0.000    0.000    0.000    0.000 :0(next)
#       420    0.001    0.000    0.001    0.000 :0(or_)
#       680    0.001    0.000    0.001    0.000 :0(pop)
#         2    0.000    0.000    0.220    0.110 :0(print)
#        80    0.000    0.000    0.000    0.000 :0(ravel)
#       820    0.002    0.000    0.002    0.000 :0(reduce)
#        80    0.000    0.000    0.000    0.000 :0(remove)
#        20    0.000    0.000    0.000    0.000 :0(repeat)
#       660    0.001    0.000    0.001    0.000 :0(replace)
#      4880    0.006    0.000    0.006    0.000 :0(reshape)
#       680    0.001    0.000    0.001    0.000 :0(rjust)
#       480    0.001    0.000    0.001    0.000 :0(seterrobj)
#         1    0.000    0.000    0.000    0.000 :0(setprofile)
#       200    0.000    0.000    0.000    0.000 :0(slice_len)
#        20    0.004    0.000    0.047    0.002 :0(sorted)
#      3720    0.004    0.000    0.004    0.000 :0(split)
#       200    0.000    0.000    0.000    0.000 :0(strip)
#      1300    0.005    0.000    0.011    0.000 :0(sum)
#        80    0.000    0.000    0.000    0.000 :0(take)
#        40    0.000    0.000    0.000    0.000 :0(take_1d_int64_int64)
#        20    0.000    0.000    0.000    0.000 :0(take_2d_axis1_object_object)
#       200    0.000    0.000    0.000    0.000 :0(transpose)
#       220    0.000    0.000    0.000    0.000 :0(upper)
#       160    0.000    0.000    0.000    0.000 :0(values)
#        60    0.000    0.000    0.000    0.000 :0(view)
#        24    0.000    0.000    0.000    0.000 :0(write)
#       240    0.000    0.000    0.000    0.000 :0(zeros)
#       220    0.001    0.000    0.090    0.000 <__array_function__ internals>:2(any)
#        20    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(argsort)
#        20    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(array_equal)
#        80    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(atleast_1d)
#        40    0.000    0.000    0.014    0.000 <__array_function__ internals>:2(atleast_2d)
#        40    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(concatenate)
#       400    0.001    0.000    0.002    0.000 <__array_function__ internals>:2(copyto)
#        20    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(dot)
#        20    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(repeat)
#        20    0.000    0.000    0.015    0.001 <__array_function__ internals>:2(vstack)
#      1940    0.006    0.000    0.010    0.000 <frozen importlib._bootstrap>:1033(_handle_fromlist)
#       200    0.000    0.000    0.001    0.000 <string>:1(<lambda>)
#     221/1    0.001    0.000    1.311    1.311 <string>:1(<module>)
#       220    0.001    0.000    0.002    0.000 __init__.py:152(align_method_SERIES)
#       200    0.002    0.000    0.046    0.000 __init__.py:207(align_method_FRAME)
#       200    0.001    0.000    0.002    0.000 __init__.py:315(should_reindex_frame_op)
#       220    0.000    0.000    0.001    0.000 _asarray.py:111(<setcomp>)
#       220    0.001    0.000    0.002    0.000 _asarray.py:22(require)
#        20    0.000    0.000    0.000    0.000 _dtype.py:178(_datetime_metadata_str)
#      4480    0.004    0.000    0.004    0.000 _dtype.py:24(_kind_name)
#      4480    0.004    0.000    0.004    0.000 _dtype.py:307(_name_includes_bit_suffix)
#      4480    0.016    0.000    0.027    0.000 _dtype.py:321(_name_get)
#       260    0.000    0.000    0.001    0.000 _methods.py:38(_amax)
#        20    0.000    0.000    0.000    0.000 _methods.py:46(_sum)
#       300    0.001    0.000    0.002    0.000 _methods.py:54(_any)
#       220    0.000    0.000    0.001    0.000 _methods.py:60(_all)
#        20    0.000    0.000    0.002    0.000 _mixins.py:266(__getitem__)
#       480    0.001    0.000    0.002    0.000 _ufunc_config.py:131(geterr)
#       480    0.002    0.000    0.005    0.000 _ufunc_config.py:32(seterr)
#       240    0.000    0.000    0.000    0.000 _ufunc_config.py:425(__init__)
#       240    0.001    0.000    0.003    0.000 _ufunc_config.py:429(__enter__)
#       240    0.001    0.000    0.003    0.000 _ufunc_config.py:434(__exit__)
#       200    0.000    0.000    0.000    0.000 _validators.py:122(_check_for_invalid_keys)
#       200    0.001    0.000    0.002    0.000 _validators.py:135(validate_kwargs)
#       200    0.000    0.000    0.001    0.000 _validators.py:218(validate_bool_kwarg)
#       200    0.000    0.000    0.001    0.000 _validators.py:43(_check_for_default_values)
#       480    0.001    0.000    0.001    0.000 abc.py:117(__instancecheck__)
#        20    0.000    0.000    0.000    0.000 abc.py:121(__subclasscheck__)
#        40    0.000    0.000    0.000    0.000 algorithms.py:1356(take)
#       220    0.001    0.000    0.002    0.000 api.py:177(union_indexes)
#        20    0.000    0.000    0.000    0.000 array_ops.py:134(_na_arithmetic_op)
#        20    0.000    0.000    0.002    0.000 array_ops.py:227(comparison_op)
#       420    0.001    0.000    0.003    0.000 array_ops.py:291(na_logical_op)
#       420    0.006    0.000    0.033    0.000 array_ops.py:332(logical_op)
#       840    0.002    0.000    0.009    0.000 array_ops.py:350(fill_bool)
#       200    0.001    0.000    0.001    0.000 array_ops.py:398(get_array_op)
#       200    0.001    0.000    0.001    0.000 array_ops.py:441(maybe_prepare_scalar_for_op)
#       640    0.004    0.000    0.018    0.000 arraylike.py:180(_maybe_fallback)
#      1720    0.002    0.000    0.003    0.000 arraylike.py:193(<genexpr>)
#      1720    0.002    0.000    0.003    0.000 arraylike.py:194(<genexpr>)
#   640/420    0.015    0.000    0.256    0.001 arraylike.py:242(array_ufunc)
#      1060    0.001    0.000    0.001    0.000 arraylike.py:284(<genexpr>)
#       420    0.001    0.000    0.002    0.000 arraylike.py:285(<listcomp>)
#        20    0.000    0.000    0.000    0.000 arraylike.py:317(<listcomp>)
#       420    0.001    0.000    0.052    0.000 arraylike.py:323(reconstruct)
#       420    0.004    0.000    0.051    0.000 arraylike.py:330(_reconstruct)
#        20    0.000    0.000    0.008    0.000 arraylike.py:38(__eq__)
#       640    0.001    0.000    0.001    0.000 arraylike.py:416(_standardize_out_kwarg)
#       220    0.003    0.000    0.155    0.001 arraylike.py:431(dispatch_ufunc_with_out)
#       220    0.001    0.000    0.008    0.000 arraylike.py:466(_assign_where)
#       200    0.000    0.000    0.074    0.000 arraylike.py:76(__or__)
#       220    0.001    0.000    0.128    0.001 arraylike.py:80(__ror__)
#        40    0.000    0.000    0.001    0.000 base.py:1106(take)
#        40    0.000    0.000    0.000    0.000 base.py:1132(_maybe_disallow_fill)
#        60    0.000    0.000    0.018    0.000 base.py:1369(format)
#        60    0.000    0.000    0.018    0.000 base.py:1391(_format_with_header)
#        20    0.000    0.000    0.005    0.000 base.py:1400(<listcomp>)
#       180    0.000    0.000    0.000    0.000 base.py:1658(name)
#        40    0.000    0.000    0.000    0.000 base.py:1906(nlevels)
#        20    0.000    0.000    0.006    0.000 base.py:210(interleaved_dtype)
#        20    0.000    0.000    0.000    0.000 base.py:2240(is_unique)
#        80    0.000    0.000    0.001    0.000 base.py:2280(is_boolean)
#       300    0.000    0.000    0.000    0.000 base.py:229(disallow_kwargs)
#       220    0.000    0.000    0.001    0.000 base.py:2352(is_floating)
#        40    0.000    0.000    0.000    0.000 base.py:2440(is_object)
#        60    0.000    0.000    0.001    0.000 base.py:2604(inferred_type)
#        20    0.000    0.000    0.000    0.000 base.py:2611(_is_all_dates)
#        80    0.000    0.000    0.000    0.000 base.py:2632(_is_multi)
#      1160    0.003    0.000    0.017    0.000 base.py:286(is_dtype)
#        20    0.000    0.000    0.000    0.000 base.py:315(shape)
#       540    0.000    0.000    0.000    0.000 base.py:326(ndim)
#        20    0.000    0.000    0.000    0.000 base.py:358(size)
#       220    0.001    0.000    0.003    0.000 base.py:3585(get_loc)
#        40    0.001    0.000    0.015    0.000 base.py:3714(get_indexer)
#        40    0.000    0.000    0.001    0.000 base.py:3794(_get_indexer)
#        40    0.000    0.000    0.002    0.000 base.py:3837(_check_indexing_method)
#   560/300    0.014    0.000    0.089    0.000 base.py:397(__new__)
#        20    0.000    0.000    0.011    0.001 base.py:4123(reindex)
#        20    0.000    0.000    0.000    0.000 base.py:4240(_wrap_reindex_result)
#        20    0.000    0.000    0.000    0.000 base.py:4244(_maybe_preserve_names)
#       120    0.000    0.000    0.001    0.000 base.py:45(__len__)
#        80    0.000    0.000    0.000    0.000 base.py:465(find)
#       880    0.001    0.000    0.001    0.000 base.py:4834(_values)
#       100    0.000    0.000    0.001    0.000 base.py:4860(_get_engine_target)
#       700    0.001    0.000    0.003    0.000 base.py:4987(__contains__)
#      1560    0.005    0.000    0.010    0.000 base.py:5037(__getitem__)
#        40    0.000    0.000    0.001    0.000 base.py:5092(_can_hold_identifiers_and_holds_name)
#       440    0.001    0.000    0.001    0.000 base.py:518(<genexpr>)
#      1480    0.003    0.000    0.007    0.000 base.py:5192(equals)
#       300    0.001    0.000    0.005    0.000 base.py:53(shape)
#       280    0.000    0.000    0.000    0.000 base.py:540(_ensure_array)
#       900    0.001    0.000    0.004    0.000 base.py:55(<genexpr>)
#       300    0.002    0.000    0.010    0.000 base.py:554(_dtype_to_subclass)
#       400    0.002    0.000    0.006    0.000 base.py:57(_validate_set_axis)
#        20    0.000    0.000    0.010    0.001 base.py:5758(get_indexer_for)
#        20    0.000    0.000    0.023    0.001 base.py:5782(_get_indexer_strict)
#        20    0.000    0.000    0.000    0.000 base.py:5813(_raise_if_missing)
#       100    0.000    0.000    0.000    0.000 base.py:5919(_index_as_unique)
#        40    0.000    0.000    0.001    0.000 base.py:5931(_maybe_promote)
#        40    0.000    0.000    0.002    0.000 base.py:6018(_should_compare)
#        40    0.000    0.000    0.000    0.000 base.py:6036(_is_comparable_dtype)
#       220    0.001    0.000    0.002    0.000 base.py:6298(_maybe_cast_indexer)
#        40    0.000    0.000    0.005    0.000 base.py:6307(_maybe_cast_listlike_indexer)
#       360    0.001    0.000    0.002    0.000 base.py:654(_simple_new)
#        80    0.001    0.000    0.024    0.000 base.py:672(_with_infer)
#        20    0.000    0.000    0.000    0.000 base.py:692(_constructor)
#      2380    0.005    0.000    0.031    0.000 base.py:7004(ensure_index)
#        20    0.000    0.000    0.000    0.000 base.py:7063(ensure_has_len)
#        40    0.000    0.000    0.001    0.000 base.py:7075(trim_front)
#       160    0.000    0.000    0.000    0.000 base.py:7089(<genexpr>)
#        40    0.000    0.000    0.000    0.000 base.py:7090(<listcomp>)
#      1120    0.003    0.000    0.010    0.000 base.py:7099(maybe_extract_name)
#       300    0.001    0.000    0.009    0.000 base.py:7123(_maybe_cast_data_without_dtype)
#        40    0.000    0.000    0.001    0.000 base.py:7185(unpack_nested_dtype)
#       100    0.000    0.000    0.001    0.000 base.py:744(__iter__)
#      1480    0.001    0.000    0.001    0.000 base.py:803(is_)
#       360    0.000    0.000    0.000    0.000 base.py:834(_reset_identity)
#        60    0.000    0.000    0.001    0.000 base.py:845(_engine)
#      8260    0.013    0.000    0.019    0.000 base.py:884(__len__)
#       120    0.000    0.000    0.000    0.000 base.py:945(dtype)
#        20    0.000    0.000    0.002    0.000 blocks.py:1116(take_nd)
#      4380    0.010    0.000    0.036    0.000 blocks.py:166(_consolidate_key)
#      5860    0.024    0.000    0.053    0.000 blocks.py:1962(maybe_coerce_values)
#      6060    0.027    0.000    0.048    0.000 blocks.py:1991(get_block_type)
#      4840    0.013    0.000    0.095    0.000 blocks.py:2032(new_block_2d)
#      1000    0.005    0.000    0.030    0.000 blocks.py:2043(new_block)
#      1000    0.003    0.000    0.008    0.000 blocks.py:2057(check_ndim)
#       280    0.001    0.000    0.002    0.000 blocks.py:2121(extend_blocks)
#      4380    0.014    0.000    0.032    0.000 blocks.py:2137(ensure_block_shape)
#       200    0.000    0.000    0.000    0.000 blocks.py:222(get_values)
#        20    0.000    0.000    0.001    0.000 blocks.py:238(fill_value)
#      5280    0.004    0.000    0.004    0.000 blocks.py:244(mgr_locs)
#       200    0.000    0.000    0.000    0.000 blocks.py:248(mgr_locs)
#       440    0.001    0.000    0.014    0.000 blocks.py:252(make_block)
#        20    0.000    0.000    0.000    0.000 blocks.py:267(make_block_same_class)
#       200    0.000    0.000    0.000    0.000 blocks.py:310(_slice)
#       200    0.000    0.000    0.001    0.000 blocks.py:332(getitem_block_columns)
#        40    0.000    0.000    0.000    0.000 blocks.py:350(shape)
#      4920    0.004    0.000    0.004    0.000 blocks.py:354(dtype)
#      4820    0.012    0.000    0.014    0.000 blocks.py:358(iget)
#       220    0.001    0.000    0.009    0.000 blocks.py:396(apply)
#       420    0.001    0.000    0.016    0.000 blocks.py:427(_split_op_result)
#        20    0.000    0.000    0.004    0.000 blocks.py:560(astype)
#       480    0.001    0.000    0.001    0.000 build.py:207(_column_combinations)
#       240    0.000    0.000    0.000    0.000 build.py:209(<listcomp>)
#       240    0.001    0.000    0.002    0.000 build.py:223(_subterm_column_combinations)
#       240    0.003    0.000    0.009    0.000 build.py:259(_build_subterm)
#        20    0.000    0.000    0.000    0.000 build.py:347(_factors_memorize)
#       200    0.000    0.000    0.001    0.000 build.py:42(_max_allowed_dim)
#        20    0.000    0.000    0.000    0.000 build.py:437(_examine_factor_types)
#        20    0.000    0.000    0.000    0.000 build.py:571(_make_subterm_infos)
#       220    0.002    0.000    0.514    0.002 build.py:61(_eval_factor)
#        20    0.001    0.000    0.003    0.000 build.py:638(design_matrix_builders)
#        40    0.002    0.000    0.020    0.001 build.py:739(_build_design_matrix)
#        40    0.000    0.000    0.000    0.000 build.py:775(__init__)
#       480    0.001    0.000    0.002    0.000 build.py:782(check)
#        20    0.004    0.000    0.690    0.035 build.py:797(build_design_matrices)
#       220    0.000    0.000    0.000    0.000 build.py:877(<lambda>)
#       220    0.000    0.000    0.001    0.000 build.py:878(<lambda>)
#        20    0.000    0.000    0.000    0.000 build.py:908(<listcomp>)
#     40/20    0.000    0.000    0.002    0.000 cast.py:1075(astype_nansafe)
#        20    0.000    0.000    0.002    0.000 cast.py:1199(astype_array)
#        20    0.000    0.000    0.003    0.000 cast.py:1246(astype_array_safe)
#      4380    0.031    0.000    0.061    0.000 cast.py:1466(maybe_infer_to_datetimelike)
#        20    0.000    0.000    0.005    0.000 cast.py:1499(try_datetime)
#       500    0.001    0.000    0.001    0.000 cast.py:1711(sanitize_to_nanoseconds)
#        20    0.001    0.000    0.005    0.000 cast.py:1789(find_common_type)
#       140    0.000    0.000    0.000    0.000 cast.py:1819(<genexpr>)
#        40    0.001    0.000    0.001    0.000 cast.py:1828(<genexpr>)
#        40    0.000    0.000    0.000    0.000 cast.py:1830(<genexpr>)
#        40    0.000    0.000    0.001    0.000 cast.py:1835(<genexpr>)
#       260    0.001    0.000    0.002    0.000 cast.py:1962(construct_1d_object_array_from_listlike)
#        20    0.000    0.000    0.001    0.000 cast.py:1987(maybe_cast_to_integer_array)
#        40    0.000    0.000    0.000    0.000 cast.py:468(maybe_promote)
#        20    0.000    0.000    0.000    0.000 categorical.py:151(_categorical_shape_fix)
#        20    0.000    0.000    0.007    0.000 categorical.py:308(categorical_to_int)
#        20    0.000    0.000    0.000    0.000 common.py:1042(is_numeric_v_string_like)
#       760    0.003    0.000    0.011    0.000 common.py:105(is_bool_indexer)
#       640    0.001    0.000    0.002    0.000 common.py:1148(needs_i8_conversion)
#       220    0.001    0.000    0.002    0.000 common.py:1198(is_numeric_dtype)
#      1000    0.003    0.000    0.009    0.000 common.py:1240(is_float_dtype)
#       880    0.005    0.000    0.012    0.000 common.py:1274(is_bool_dtype)
#      6540    0.010    0.000    0.015    0.000 common.py:1416(is_1d_only_ea_dtype)
#       860    0.003    0.000    0.005    0.000 common.py:1429(is_extension_array_dtype)
#      2680    0.002    0.000    0.002    0.000 common.py:145(classes)
#      2680    0.004    0.000    0.006    0.000 common.py:147(<lambda>)
#      1120    0.003    0.000    0.004    0.000 common.py:1483(is_ea_or_datetimelike_dtype)
#       320    0.001    0.000    0.003    0.000 common.py:1496(is_complex_dtype)
#      2260    0.002    0.000    0.002    0.000 common.py:150(classes_and_not_datetimelike)
#      2260    0.005    0.000    0.007    0.000 common.py:155(<lambda>)
#      1560    0.002    0.000    0.004    0.000 common.py:1552(get_dtype)
#      4940    0.014    0.000    0.032    0.000 common.py:1587(_is_dtype_type)
#      1760    0.003    0.000    0.004    0.000 common.py:160(cast_scalar_indexer)
#      1340    0.004    0.000    0.014    0.000 common.py:161(is_object_dtype)
#      1100    0.002    0.000    0.010    0.000 common.py:1721(validate_all_hashable)
#      2200    0.003    0.000    0.005    0.000 common.py:1740(<genexpr>)
#       600    0.002    0.000    0.004    0.000 common.py:1747(pandas_dtype)
#       560    0.003    0.000    0.009    0.000 common.py:229(asarray_tuplesafe)
#       220    0.001    0.000    0.003    0.000 common.py:287(maybe_iterable_to_list)
#       240    0.000    0.000    0.001    0.000 common.py:297(is_null_slice)
#       360    0.001    0.000    0.001    0.000 common.py:315(is_datetime64_dtype)
#       720    0.001    0.000    0.002    0.000 common.py:346(apply_if_callable)
#       540    0.001    0.000    0.010    0.000 common.py:348(is_datetime64tz_dtype)
#       340    0.001    0.000    0.001    0.000 common.py:389(is_timedelta64_dtype)
#        20    0.000    0.000    0.000    0.000 common.py:423(is_period_dtype)
#        40    0.000    0.000    0.001    0.000 common.py:459(is_interval_dtype)
#       560    0.001    0.000    0.010    0.000 common.py:497(is_categorical_dtype)
#       220    0.000    0.000    0.000    0.000 common.py:533(is_string_or_object_np_dtype)
#       440    0.002    0.000    0.217    0.000 common.py:55(new_method)
#       560    0.001    0.000    0.004    0.000 common.py:552(require_length_match)
#       340    0.002    0.000    0.004    0.000 common.py:581(is_dtype_equal)
#      1420    0.004    0.000    0.014    0.000 common.py:680(is_integer_dtype)
#       320    0.001    0.000    0.003    0.000 common.py:732(is_signed_integer_dtype)
#       240    0.001    0.000    0.004    0.000 common.py:75(get_op_result_name)
#       300    0.001    0.000    0.003    0.000 common.py:786(is_unsigned_integer_dtype)
#       180    0.001    0.000    0.002    0.000 common.py:97(_maybe_match_name)
#       220    0.001    0.000    0.030    0.000 compat.py:34(call_and_wrap_exc)
#      3740    0.020    0.000    0.049    0.000 config.py:109(_get_single_key)
#      3660    0.011    0.000    0.071    0.000 config.py:127(_get_option)
#        40    0.001    0.000    0.003    0.000 config.py:135(_set_option)
#        40    0.000    0.000    0.001    0.000 config.py:199(get_default_val)
#      3640    0.007    0.000    0.078    0.000 config.py:255(__call__)
#        20    0.000    0.000    0.000    0.000 config.py:425(__init__)
#        20    0.000    0.000    0.002    0.000 config.py:433(__enter__)
#        20    0.000    0.000    0.000    0.000 config.py:434(<listcomp>)
#        20    0.000    0.000    0.001    0.000 config.py:439(__exit__)
#      3740    0.004    0.000    0.004    0.000 config.py:571(_select_options)
#      3700    0.008    0.000    0.012    0.000 config.py:589(_get_root)
#      7380    0.007    0.000    0.007    0.000 config.py:603(_get_deprecated_option)
#        80    0.000    0.000    0.000    0.000 config.py:619(_get_registered_option)
#      3740    0.006    0.000    0.010    0.000 config.py:630(_translate_key)
#      3640    0.006    0.000    0.010    0.000 config.py:642(_warn_if_deprecated)
#        40    0.000    0.000    0.000    0.000 config.py:825(inner)
#        40    0.000    0.000    0.001    0.000 config_init.py:380(_deprecate_negative_int_max_colwidth)
#        20    0.000    0.000    0.000    0.000 console.py:53(in_interactive_session)
#        20    0.000    0.000    0.000    0.000 console.py:78(in_ipython_frontend)
#        20    0.000    0.000    0.002    0.000 console.py:8(get_console_size)
#       220    0.002    0.000    0.026    0.000 construction.py:102(arrays_to_mgr)
#       680    0.002    0.000    0.002    0.000 construction.py:233(mgr_to_mgr)
#       460    0.009    0.000    0.352    0.001 construction.py:274(ndarray_to_mgr)
#      1300    0.003    0.000    0.019    0.000 construction.py:379(extract_array)
#        20    0.006    0.000    0.066    0.003 construction.py:382(<listcomp>)
#        80    0.000    0.000    0.000    0.000 construction.py:384(<genexpr>)
#        20    0.004    0.000    0.036    0.002 construction.py:385(<listcomp>)
#        20    0.007    0.000    0.092    0.005 construction.py:386(<listcomp>)
#       460    0.001    0.000    0.005    0.000 construction.py:407(_check_values_indices_shape_match)
#       220    0.003    0.000    0.112    0.001 construction.py:425(dict_to_mgr)
#      6900    0.013    0.000    0.019    0.000 construction.py:438(ensure_wrapped_if_datetimelike)
#       820    0.012    0.000    0.055    0.000 construction.py:470(sanitize_array)
#       220    0.000    0.000    0.003    0.000 construction.py:483(<listcomp>)
#       220    0.000    0.000    0.001    0.000 construction.py:486(<listcomp>)
#       220    0.000    0.000    0.005    0.000 construction.py:487(<listcomp>)
#       220    0.001    0.000    0.002    0.000 construction.py:494(<listcomp>)
#       460    0.002    0.000    0.004    0.000 construction.py:549(_prep_ndarray)
#       220    0.001    0.000    0.003    0.000 construction.py:596(_homogenize)
#       820    0.002    0.000    0.007    0.000 construction.py:630(_sanitize_ndim)
#       220    0.002    0.000    0.006    0.000 construction.py:635(_extract_index)
#       820    0.001    0.000    0.002    0.000 construction.py:667(_sanitize_str_dtypes)
#       820    0.002    0.000    0.004    0.000 construction.py:687(_maybe_repeat)
#       820    0.004    0.000    0.012    0.000 construction.py:698(_try_cast)
#       460    0.001    0.000    0.019    0.000 construction.py:747(_get_axes)
#       560    0.002    0.000    0.003    0.000 construction.py:805(is_empty_data)
#        20    0.000    0.000    0.000    0.000 contextlib.py:114(__enter__)
#        20    0.000    0.000    0.000    0.000 contextlib.py:123(__exit__)
#        20    0.000    0.000    0.000    0.000 contextlib.py:261(helper)
#       240    0.000    0.000    0.000    0.000 contextlib.py:376(__init__)
#       240    0.000    0.000    0.000    0.000 contextlib.py:379(__enter__)
#       240    0.000    0.000    0.000    0.000 contextlib.py:382(__exit__)
#        20    0.000    0.000    0.000    0.000 contextlib.py:86(__init__)
#        20    0.000    0.000    0.000    0.000 data.py:94(_is_using_pandas)
#        20    0.000    0.000    0.002    0.000 datetimelike.py:330(__getitem__)
#        40    0.000    0.000    0.000    0.000 datetimelike.py:880(freq)
#        20    0.000    0.000    0.005    0.000 datetimes.py:2004(sequence_to_datetimes)
#        20    0.001    0.000    0.005    0.000 datetimes.py:2019(_sequence_to_dt64ns)
#        20    0.000    0.000    0.001    0.000 datetimes.py:2176(objects_to_datetime64ns)
#        20    0.000    0.000    0.002    0.000 datetimes.py:2268(maybe_convert_dtype)
#        20    0.000    0.000    0.000    0.000 datetimes.py:2359(_validate_dt64_dtype)
#        40    0.000    0.000    0.000    0.000 datetimes.py:2401(validate_tz_from_dtype)
#        20    0.000    0.000    0.000    0.000 datetimes.py:326(_simple_new)
#        20    0.001    0.000    0.001    0.000 datetimes.py:530(_box_func)
#       100    0.000    0.000    0.000    0.000 datetimes.py:545(dtype)
#        20    0.000    0.000    0.000    0.000 datetimes.py:570(tz)
#        20    0.000    0.000    0.000    0.000 datetimes.py:96(tz_to_dtype)
#       480    0.001    0.000    0.002    0.000 desc.py:53(__hash__)
#        60    0.001    0.000    0.005    0.000 design_info.py:1014(__new__)
#        20    0.001    0.000    0.002    0.000 design_info.py:271(__init__)
#        20    0.000    0.000    0.000    0.000 design_info.py:361(<listcomp>)
#       160    0.000    0.000    0.000    0.000 design_info.py:401(column_names)
#       440    0.001    0.000    0.005    0.000 dispatch.py:11(should_extension_dispatch)
#        40    0.000    0.000    0.001    0.000 dtypes.py:1206(is_dtype)
#        20    0.000    0.000    0.000    0.000 dtypes.py:955(is_dtype)
#        80    0.000    0.000    0.000    0.000 enum.py:792(value)
#        20    0.000    0.000    0.000    0.000 eval.py:136(__init__)
#       220    0.001    0.000    0.029    0.000 eval.py:155(eval)
#        40    0.000    0.000    0.001    0.000 eval.py:168(capture)
#       440    0.000    0.000    0.000    0.000 eval.py:42(__init__)
#   440/220    0.001    0.000    0.026    0.000 eval.py:45(__getitem__)
#       220    0.000    0.000    0.000    0.000 eval.py:451(name)
#      2620    0.004    0.000    0.006    0.000 eval.py:464(__hash__)
#       220    0.001    0.000    0.031    0.000 eval.py:545(_eval)
#       220    0.000    0.000    0.031    0.000 eval.py:563(eval)
#        20    0.000    0.000    0.000    0.000 expressions.py:223(evaluate)
#        20    0.000    0.000    0.000    0.000 expressions.py:63(_evaluate_standard)
#        20    0.000    0.000    0.000    0.000 expressions.py:72(_can_use_numexpr)
#        20    0.000    0.000    0.000    0.000 expressions.py:92(_evaluate_numexpr)
#      2340    0.003    0.000    0.003    0.000 flags.py:47(__init__)
#      1180    0.001    0.000    0.001    0.000 flags.py:51(allows_duplicate_labels)
#      1180    0.001    0.000    0.001    0.000 flags.py:83(allows_duplicate_labels)
#        20    0.000    0.000    0.000    0.000 format.py:1019(__init__)
#        20    0.000    0.000    0.185    0.009 format.py:1105(to_string)
#        20    0.000    0.000    0.001    0.000 format.py:1191(save_to_buffer)
#        40    0.000    0.000    0.000    0.000 format.py:1206(get_buffer)
#       280    0.004    0.000    0.072    0.000 format.py:1240(format_array)
#       280    0.000    0.000    0.000    0.000 format.py:1320(__init__)
#       280    0.001    0.000    0.035    0.000 format.py:1346(get_result)
#        20    0.000    0.000    0.000    0.000 format.py:1426(__init__)
#        20    0.000    0.000    0.000    0.000 format.py:1438(_value_formatter)
#        20    0.000    0.000    0.000    0.000 format.py:1456(base_formatter)
#        20    0.000    0.000    0.005    0.000 format.py:1494(get_result_as_array)
#        20    0.000    0.000    0.001    0.000 format.py:1500(format_with_na_rep)
#        20    0.000    0.000    0.000    0.000 format.py:1503(<listcomp>)
#        20    0.000    0.000    0.003    0.000 format.py:1519(format_values_with)
#        40    0.000    0.000    0.000    0.000 format.py:1568(<genexpr>)
#        20    0.000    0.000    0.005    0.000 format.py:1593(_format_strings)
#       260    0.001    0.000    0.002    0.000 format.py:1598(_format_strings)
#       260    0.001    0.000    0.001    0.000 format.py:1602(<lambda>)
#       260    0.001    0.000    0.001    0.000 format.py:1604(<listcomp>)
#       520    0.004    0.000    0.039    0.000 format.py:1884(_make_fixed_width)
#      1040    0.001    0.000    0.003    0.000 format.py:1899(<genexpr>)
#       520    0.001    0.000    0.002    0.000 format.py:1908(just)
#       520    0.001    0.000    0.003    0.000 format.py:1914(<listcomp>)
#        20    0.000    0.000    0.001    0.000 format.py:1956(_trim_zeros_float)
#        42    0.000    0.000    0.000    0.000 format.py:1967(is_number_with_decimal)
#        21    0.000    0.000    0.001    0.000 format.py:1970(should_trim)
#        21    0.000    0.000    0.000    0.000 format.py:1978(<listcomp>)
#        42    0.000    0.000    0.000    0.000 format.py:1979(<genexpr>)
#         1    0.000    0.000    0.000    0.000 format.py:1982(<listcomp>)
#        20    0.000    0.000    0.000    0.000 format.py:1985(<listcomp>)
#        60    0.000    0.000    0.000    0.000 format.py:1992(_has_names)
#        20    0.000    0.000    0.002    0.000 format.py:263(__init__)
#        20    0.000    0.000    0.000    0.000 format.py:295(_chk_truncate)
#        20    0.000    0.000    0.002    0.000 format.py:322(_get_footer)
#        20    0.000    0.000    0.006    0.000 format.py:363(_get_formatted_index)
#        20    0.000    0.000    0.009    0.000 format.py:374(_get_formatted_values)
#        20    0.000    0.000    0.018    0.001 format.py:383(to_string)
#       320    0.001    0.000    0.007    0.000 format.py:423(__init__)
#      2500    0.004    0.000    0.006    0.000 format.py:426(len)
#      1100    0.002    0.000    0.007    0.000 format.py:429(justify)
#        80    0.000    0.000    0.010    0.000 format.py:432(adjoin)
#       320    0.001    0.000    0.015    0.000 format.py:475(get_adjustment)
#        20    0.000    0.000    0.005    0.000 format.py:483(get_dataframe_repr_params)
#        20    0.000    0.000    0.003    0.000 format.py:516(get_series_repr_params)
#        20    0.000    0.000    0.003    0.000 format.py:560(__init__)
#        20    0.000    0.000    0.169    0.008 format.py:607(get_strcols)
#        20    0.000    0.000    0.000    0.000 format.py:619(should_show_dimensions)
#        40    0.000    0.000    0.001    0.000 format.py:625(is_truncated)
#        60    0.000    0.000    0.000    0.000 format.py:629(is_truncated_horizontally)
#        80    0.000    0.000    0.001    0.000 format.py:633(is_truncated_vertically)
#        40    0.000    0.000    0.000    0.000 format.py:641(has_index_names)
#        20    0.000    0.000    0.000    0.000 format.py:645(has_column_names)
#        40    0.000    0.000    0.000    0.000 format.py:649(show_row_idx_names)
#        20    0.000    0.000    0.000    0.000 format.py:653(show_col_idx_names)
#        20    0.000    0.000    0.000    0.000 format.py:661(_initialize_sparsify)
#        20    0.000    0.000    0.000    0.000 format.py:666(_initialize_formatters)
#        20    0.000    0.000    0.000    0.000 format.py:679(_initialize_justify)
#        20    0.000    0.000    0.000    0.000 format.py:685(_initialize_columns)
#        20    0.000    0.000    0.000    0.000 format.py:693(_initialize_colspace)
#        20    0.000    0.000    0.000    0.000 format.py:717(_calc_max_cols_fitted)
#        20    0.000    0.000    0.000    0.000 format.py:728(_calc_max_rows_fitted)
#        20    0.000    0.000    0.000    0.000 format.py:747(_adjust_max_rows)
#        40    0.000    0.000    0.000    0.000 format.py:761(_is_in_terminal)
#        20    0.000    0.000    0.000    0.000 format.py:785(truncate)
#        20    0.003    0.000    0.161    0.008 format.py:839(_get_strcols_without_index)
#       440    0.001    0.000    0.001    0.000 format.py:873(<genexpr>)
#       440    0.001    0.000    0.001    0.000 format.py:880(<genexpr>)
#       220    0.002    0.000    0.122    0.001 format.py:886(format_col)
#       460    0.002    0.000    0.007    0.000 format.py:899(_get_formatter)
#        20    0.000    0.000    0.019    0.001 format.py:911(_get_formatted_column_labels)
#        20    0.000    0.000    0.004    0.000 format.py:945(<listcomp>)
#        20    0.000    0.000    0.008    0.000 format.py:952(_get_formatted_index)
#        20    0.000    0.000    0.000    0.000 format.py:955(<dictcomp>)
#        20    0.000    0.000    0.001    0.000 format.py:970(<listcomp>)
#        20    0.000    0.000    0.197    0.010 frame.py:1001(__repr__)
#       200    0.000    0.000    0.000    0.000 frame.py:10314(_get_agg_axis)
#       200    0.001    0.000    0.006    0.000 frame.py:10817(values)
#        20    0.000    0.000    0.192    0.010 frame.py:1107(to_string)
#       180    0.000    0.000    0.001    0.000 frame.py:1413(__len__)
#        20    0.000    0.000    0.297    0.015 frame.py:3273(transpose)
#        20    0.000    0.000    0.297    0.015 frame.py:3404(T)
#       460    0.003    0.000    0.057    0.000 frame.py:3411(_ixs)
#       240    0.003    0.000    0.058    0.000 frame.py:3463(__getitem__)
#       440    0.002    0.000    0.014    0.000 frame.py:3906(_box_col_values)
#       400    0.001    0.000    0.001    0.000 frame.py:3920(_clear_item_cache)
#       220    0.001    0.000    0.018    0.000 frame.py:3923(_get_item_cache)
#      1060    0.001    0.000    0.001    0.000 frame.py:578(_constructor)
#      1320    0.017    0.000    0.514    0.000 frame.py:587(__init__)
#       200    0.002    0.000    0.120    0.001 frame.py:6946(_arith_method)
#       200    0.003    0.000    0.053    0.000 frame.py:6960(_dispatch_frame_op)
#       200    0.001    0.000    0.014    0.000 frame.py:7055(_construct_result)
#       640    0.001    0.000    0.001    0.000 frame.py:804(axes)
#      1040    0.003    0.000    0.011    0.000 frame.py:821(shape)
#        20    0.000    0.000    0.000    0.000 frame.py:881(_can_fast_transpose)
#       640    0.003    0.000    0.016    0.000 frame.py:898(_values)
#        20    0.000    0.000    0.000    0.000 frame.py:992(_info_repr)
#       200    0.003    0.000    0.078    0.000 frame.py:9940(_reduce)
#       200    0.000    0.000    0.021    0.000 frame.py:9983(func)
#        20    0.000    0.000    0.000    0.000 fromnumeric.py:1002(_argsort_dispatcher)
#        20    0.000    0.000    0.000    0.000 fromnumeric.py:1006(argsort)
#       220    0.000    0.000    0.000    0.000 fromnumeric.py:2263(_any_dispatcher)
#       220    0.001    0.000    0.088    0.000 fromnumeric.py:2268(any)
#        20    0.000    0.000    0.000    0.000 fromnumeric.py:432(_repeat_dispatcher)
#        20    0.000    0.000    0.000    0.000 fromnumeric.py:436(repeat)
#        40    0.000    0.000    0.000    0.000 fromnumeric.py:51(_wrapfunc)
#       220    0.001    0.000    0.088    0.000 fromnumeric.py:69(_wrapreduction)
#       220    0.000    0.000    0.000    0.000 fromnumeric.py:70(<dictcomp>)
#       240    0.001    0.000    0.003    0.000 function.py:49(__call__)
#       200    0.002    0.000    0.084    0.000 generic.py:10400(_logical_func)
#       200    0.001    0.000    0.085    0.000 generic.py:10458(any)
#       200    0.000    0.000    0.085    0.000 generic.py:10880(any)
#       200    0.002    0.000    0.088    0.000 generic.py:11344(_inplace_method)
#       200    0.001    0.000    0.089    0.000 generic.py:11406(__ior__)
#       400    0.001    0.000    0.009    0.000 generic.py:1399(_indexed_same)
#      1000    0.003    0.000    0.007    0.000 generic.py:1401(<genexpr>)
#        20    0.000    0.000    0.003    0.000 generic.py:1516(__invert__)
#        20    0.000    0.000    0.000    0.000 generic.py:1945(__iter__)
#        20    0.000    0.000    0.001    0.000 generic.py:1996(empty)
#        60    0.000    0.000    0.000    0.000 generic.py:2054(<genexpr>)
#       620    0.002    0.000    0.018    0.000 generic.py:2063(__array__)
#   640/420    0.003    0.000    0.258    0.001 generic.py:2097(__array_ufunc__)
#      2340    0.006    0.000    0.009    0.000 generic.py:239(__init__)
#      1180    0.001    0.000    0.001    0.000 generic.py:328(attrs)
#      2360    0.002    0.000    0.002    0.000 generic.py:349(flags)
#        20    0.000    0.000    0.008    0.000 generic.py:3609(take)
#        20    0.000    0.000    0.009    0.000 generic.py:3708(_take_with_is_copy)
#        40    0.000    0.000    0.000    0.000 generic.py:3925(_set_is_copy)
#     16660    0.027    0.000    0.041    0.000 generic.py:43(_check)
#        60    0.000    0.000    0.001    0.000 generic.py:441(_validate_dtype)
#      2220    0.002    0.000    0.002    0.000 generic.py:546(_get_axis_number)
#      1180    0.009    0.000    0.020    0.000 generic.py:5517(__finalize__)
#      2460    0.003    0.000    0.004    0.000 generic.py:5561(__getattr__)
#      2820    0.006    0.000    0.029    0.000 generic.py:5577(__setattr__)
#      2000    0.004    0.000    0.006    0.000 generic.py:560(_get_axis)
#       860    0.004    0.000    0.013    0.000 generic.py:5632(_protect_consolidate)
#       860    0.002    0.000    0.014    0.000 generic.py:5646(_consolidate_inplace)
#       860    0.002    0.000    0.006    0.000 generic.py:5650(f)
#        20    0.000    0.000    0.000    0.000 generic.py:566(_get_block_manager_axis)
#        40    0.000    0.000    0.012    0.000 generic.py:5718(dtypes)
#        20    0.000    0.000    0.006    0.000 generic.py:5749(astype)
#       100    0.000    0.000    0.000    0.000 generic.py:636(_info_axis)
#      2660    0.002    0.000    0.002    0.000 generic.py:660(ndim)
#       400    0.001    0.000    0.010    0.000 generic.py:767(_set_axis)
#        20    0.000    0.000    0.693    0.035 highlevel.py:154(_do_highlevel_design)
#        20    0.000    0.000    0.000    0.000 highlevel.py:162(data_iter_maker)
#        20    0.000    0.000    0.694    0.035 highlevel.py:225(dmatrix)
#        20    0.000    0.000    0.003    0.000 highlevel.py:33(_try_incr_builders)
#       240    0.000    0.000    0.000    0.000 indexing.py:130(iloc)
#       480    0.002    0.000    0.012    0.000 indexing.py:1346(_validate_key)
#       240    0.001    0.000    0.003    0.000 indexing.py:1422(_is_scalar_access)
#       500    0.001    0.000    0.001    0.000 indexing.py:1435(<genexpr>)
#       480    0.001    0.000    0.005    0.000 indexing.py:1437(_validate_integer)
#       240    0.002    0.000    0.083    0.000 indexing.py:1459(_getitem_tuple)
#       240    0.002    0.000    0.055    0.000 indexing.py:1490(_getitem_axis)
#        20    0.000    0.000    0.000    0.000 indexing.py:2323(convert_to_index_sliceable)
#       460    0.001    0.000    0.002    0.000 indexing.py:2459(is_label_like)
#       480    0.002    0.000    0.008    0.000 indexing.py:2486(check_deprecated_indexers)
#       720    0.001    0.000    0.001    0.000 indexing.py:2491(<genexpr>)
#       720    0.001    0.000    0.001    0.000 indexing.py:2502(<genexpr>)
#       240    0.001    0.000    0.002    0.000 indexing.py:740(_expand_ellipsis)
#       720    0.001    0.000    0.001    0.000 indexing.py:745(<genexpr>)
#       240    0.001    0.000    0.016    0.000 indexing.py:761(_validate_tuple_indexer)
#       240    0.001    0.000    0.003    0.000 indexing.py:777(_is_nested_tuple_indexer)
#       720    0.001    0.000    0.001    0.000 indexing.py:783(<genexpr>)
#       480    0.001    0.000    0.001    0.000 indexing.py:804(_validate_key_length)
#       240    0.003    0.000    0.065    0.000 indexing.py:834(_getitem_lowerdim)
#       240    0.002    0.000    0.098    0.000 indexing.py:954(__getitem__)
#       720    0.001    0.000    0.001    0.000 indexing.py:957(<genexpr>)
#       720    0.001    0.000    0.002    0.000 indexing.py:958(<genexpr>)
#       800    0.001    0.000    0.002    0.000 inference.py:184(is_array_like)
#        20    0.000    0.000    0.000    0.000 inference.py:262(is_dict_like)
#        40    0.000    0.000    0.000    0.000 inference.py:288(<genexpr>)
#      2520    0.004    0.000    0.006    0.000 inference.py:321(is_hashable)
#       240    0.001    0.000    0.001    0.000 inference.py:359(is_sequence)
#        20    0.000    0.000    0.000    0.000 inspect.py:1548(currentframe)
#        20    0.000    0.000    0.000    0.000 inspect.py:73(isclass)
#        20    0.000    0.000    0.000    0.000 interactiveshell.py:707(get_ipython)
#         1    0.000    0.000    0.000    0.000 iostream.py:202(schedule)
#         4    0.000    0.000    0.000    0.000 iostream.py:429(_is_master_process)
#         4    0.000    0.000    0.000    0.000 iostream.py:448(_schedule_flush)
#         4    0.000    0.000    0.000    0.000 iostream.py:518(write)
#         1    0.000    0.000    0.000    0.000 iostream.py:90(_event_pipe)
#        20    0.000    0.000    0.000    0.000 linear_model.py:355(predict)
#       440    0.003    0.000    0.006    0.000 managers.py:1026(iget)
#       200    0.001    0.000    0.038    0.000 managers.py:1415(operate_blockwise)
#       200    0.001    0.000    0.003    0.000 managers.py:1551(as_array)
#       500    0.000    0.000    0.001    0.000 managers.py:156(blknos)
#      1540    0.002    0.000    0.014    0.000 managers.py:1675(is_consolidated)
#       880    0.002    0.000    0.012    0.000 managers.py:1683(_consolidate_check)
#        40    0.006    0.000    0.009    0.000 managers.py:1689(<listcomp>)
#       680    0.001    0.000    0.093    0.000 managers.py:1693(_consolidate_inplace)
#      1020    0.001    0.000    0.001    0.000 managers.py:1714(__init__)
#       460    0.000    0.000    0.000    0.000 managers.py:172(blklocs)
#        20    0.000    0.000    0.000    0.000 managers.py:1736(from_blocks)
#       560    0.002    0.000    0.022    0.000 managers.py:1745(from_array)
#      1020    0.001    0.000    0.001    0.000 managers.py:1806(_block)
#      1400    0.002    0.000    0.003    0.000 managers.py:1851(dtype)
#      1860    0.002    0.000    0.003    0.000 managers.py:1862(internal_values)
#       460    0.002    0.000    0.094    0.000 managers.py:1925(create_block_manager_from_blocks)
#       220    0.001    0.000    0.014    0.000 managers.py:1951(create_block_manager_from_column_arrays)
#       220    0.001    0.000    0.001    0.000 managers.py:2006(_grouping_func)
#       220    0.003    0.000    0.011    0.000 managers.py:2022(_form_blocks)
#       220    0.001    0.000    0.002    0.000 managers.py:2074(_stack_arrays)
#        20    0.004    0.000    0.079    0.004 managers.py:2088(_consolidate)
#      8760    0.011    0.000    0.047    0.000 managers.py:2093(<lambda>)
#        40    0.000    0.000    0.025    0.001 managers.py:2105(_merge_blocks)
#        20    0.004    0.000    0.008    0.000 managers.py:2116(<listcomp>)
#       400    0.001    0.000    0.006    0.000 managers.py:212(set_axis)
#        20    0.000    0.000    0.000    0.000 managers.py:2125(<listcomp>)
#       220    0.001    0.000    0.001    0.000 managers.py:2151(_preprocess_slice_or_indexer)
#       420    0.001    0.000    0.001    0.000 managers.py:217(is_single_block)
#       320    0.000    0.000    0.000    0.000 managers.py:222(items)
#        40    0.000    0.000    0.001    0.000 managers.py:226(get_dtypes)
#        40    0.000    0.000    0.000    0.000 managers.py:227(<listcomp>)
#       200    0.000    0.000    0.001    0.000 managers.py:230(arrays)
#       200    0.000    0.000    0.000    0.000 managers.py:239(<listcomp>)
#       240    0.002    0.000    0.018    0.000 managers.py:253(apply)
#       240    0.000    0.000    0.000    0.000 managers.py:282(<dictcomp>)
#        20    0.000    0.000    0.004    0.000 managers.py:418(astype)
#       860    0.001    0.000    0.003    0.000 managers.py:618(consolidate)
#        20    0.000    0.000    0.005    0.000 managers.py:634(reindex_indexer)
#       220    0.002    0.000    0.012    0.000 managers.py:710(_slice_take_blocks_ax0)
#        20    0.000    0.000    0.007    0.000 managers.py:872(take)
#      1120    0.001    0.000    0.001    0.000 managers.py:916(__init__)
#       240    0.001    0.000    0.001    0.000 managers.py:970(from_blocks)
#        20    0.005    0.000    0.026    0.001 managers.py:980(fast_xs)
#        20    0.000    0.000    0.000    0.000 managers.py:995(<listcomp>)
#        40    0.000    0.000    0.000    0.000 missing.py:107(clean_fill_method)
#        20    0.000    0.000    0.000    0.000 missing.py:119(is_categorical_NA)
#       200    0.002    0.000    0.335    0.002 missing.py:129(is_numerical_NA)
#        20    0.000    0.000    0.000    0.000 missing.py:138(dispatch_fill_zeros)
#        20    0.000    0.000    0.112    0.006 missing.py:141(handle_NA)
#       260    0.001    0.000    0.005    0.000 missing.py:150(_isna)
#        20    0.000    0.000    0.112    0.006 missing.py:175(_handle_NA_drop)
#        20    0.001    0.000    0.004    0.000 missing.py:181(<listcomp>)
#       220    0.001    0.000    0.002    0.000 missing.py:227(_isna_array)
#       220    0.001    0.000    0.006    0.000 missing.py:288(notna)
#        80    0.000    0.000    0.000    0.000 missing.py:391(array_equivalent)
#        20    0.000    0.000    0.001    0.000 missing.py:572(na_value_for_dtype)
#       260    0.001    0.000    0.005    0.000 missing.py:67(isna)
#        40    0.000    0.000    0.000    0.000 missing.py:88(__init__)
#        40    0.000    0.000    0.000    0.000 missing.py:911(clean_reindex_fill_method)
#        20    0.001    0.000    0.701    0.035 model.py:1065(predict)
#       400    0.000    0.000    0.000    0.000 multiarray.py:1071(copyto)
#        40    0.000    0.000    0.000    0.000 multiarray.py:148(concatenate)
#        20    0.000    0.000    0.000    0.000 multiarray.py:736(dot)
#       200    0.000    0.000    0.000    0.000 nanops.py:191(_get_fill_value)
#       200    0.000    0.000    0.003    0.000 nanops.py:213(_maybe_get_mask)
#       200    0.002    0.000    0.015    0.000 nanops.py:257(_get_values)
#       200    0.001    0.000    0.001    0.000 nanops.py:346(_na_ok_dtype)
#       200    0.001    0.000    0.021    0.000 nanops.py:488(nanany)
#        20    0.000    0.000    0.001    0.000 numeric.py:139(_ensure_array)
#        20    0.000    0.000    0.001    0.000 numeric.py:188(_validate_dtype)
#        20    0.000    0.000    0.000    0.000 numeric.py:199(_ensure_dtype)
#        20    0.000    0.000    0.000    0.000 numeric.py:2381(_array_equal_dispatcher)
#        20    0.000    0.000    0.000    0.000 numeric.py:2385(array_equal)
#       400    0.002    0.000    0.005    0.000 numeric.py:289(full)
#       520    0.000    0.000    0.000    0.000 numeric.py:331(_is_all_dates)
#       840    0.001    0.000    0.002    0.000 numerictypes.py:284(issubclass_)
#       420    0.002    0.000    0.004    0.000 numerictypes.py:358(issubdtype)
#       200    0.001    0.000    0.001    0.000 ops.py:101(_get_same_shape_values)
#       400    0.002    0.000    0.010    0.000 ops.py:27(_iter_block_pairs)
#       200    0.002    0.000    0.038    0.000 ops.py:55(operate_blockwise)
#       200    0.001    0.000    0.001    0.000 ops.py:89(_reset_block_mgr_locs)
#        40    0.000    0.000    0.000    0.000 os.py:674(__getitem__)
#        40    0.000    0.000    0.000    0.000 os.py:754(encode)
#       240    0.001    0.000    0.005    0.000 printing.py:164(pprint_thing)
#       240    0.001    0.000    0.002    0.000 printing.py:195(as_escaped_string)
#        80    0.003    0.000    0.010    0.000 printing.py:27(adjoin)
#        80    0.000    0.000    0.002    0.000 printing.py:48(<listcomp>)
#      1100    0.002    0.000    0.005    0.000 printing.py:62(justify)
#       420    0.001    0.000    0.002    0.000 printing.py:67(<listcomp>)
#       680    0.001    0.000    0.002    0.000 printing.py:71(<listcomp>)
#         1    0.000    0.000    1.311    1.311 profile:0(print(predict(20));print('=' * 100))
#         0    0.000             0.000          profile:0(profiler)
#        20    0.000    0.000    0.000    0.000 random.py:237(_randbelow_with_getrandbits)
#        20    0.000    0.000    0.000    0.000 random.py:290(randrange)
#        20    0.000    0.000    0.000    0.000 random.py:334(randint)
#        60    0.000    0.000    0.000    0.000 range.py:909(__len__)
#        20    0.000    0.000    0.000    0.000 range.py:919(__getitem__)
#        42    0.000    0.000    0.000    0.000 re.py:188(match)
#       100    0.000    0.000    0.001    0.000 re.py:250(compile)
#       142    0.000    0.000    0.001    0.000 re.py:289(_compile)
#       220    0.000    0.000    0.001    0.000 roperator.py:55(ror_)
#       440    0.001    0.000    0.002    0.000 series.py:1238(_set_as_cached)
#        20    0.000    0.000    0.023    0.001 series.py:1499(__repr__)
#        20    0.000    0.000    0.020    0.001 series.py:1506(to_string)
#       240    0.002    0.000    0.057    0.000 series.py:2988(_construct_result)
#      1020    0.012    0.000    0.114    0.000 series.py:323(__init__)
#       280    0.000    0.000    0.000    0.000 series.py:523(_constructor)
#       560    0.001    0.000    0.002    0.000 series.py:542(_set_axis)
#        20    0.000    0.000    0.008    0.000 series.py:5613(_cmp_method)
#       220    0.002    0.000    0.081    0.000 series.py:5627(_logical_method)
#      1400    0.002    0.000    0.005    0.000 series.py:575(dtype)
#      2560    0.003    0.000    0.003    0.000 series.py:590(name)
#      1100    0.002    0.000    0.012    0.000 series.py:640(name)
#      1860    0.003    0.000    0.006    0.000 series.py:687(_values)
#       100    0.000    0.000    0.001    0.000 series.py:743(__len__)
#       300    0.001    0.000    0.002    0.000 series.py:825(__array__)
#        20    0.000    0.000    0.000    0.000 series.py:885(axes)
#        80    0.000    0.000    0.000    0.000 shape_base.py:19(_atleast_1d_dispatcher)
#        20    0.000    0.000    0.000    0.000 shape_base.py:207(_arrays_for_stack_dispatcher)
#        20    0.000    0.000    0.000    0.000 shape_base.py:218(_vhstack_dispatcher)
#        20    0.000    0.000    0.015    0.001 shape_base.py:222(vstack)
#        80    0.000    0.000    0.001    0.000 shape_base.py:23(atleast_1d)
#        40    0.000    0.000    0.000    0.000 shape_base.py:77(_atleast_2d_dispatcher)
#        40    0.007    0.000    0.014    0.000 shape_base.py:81(atleast_2d)
#        20    0.000    0.000    0.000    0.000 shutil.py:1342(get_terminal_size)
#        80    0.000    0.000    0.000    0.000 six.py:601(itervalues)
#       240    0.001    0.000    0.001    0.000 six.py:604(iteritems)
#         1    0.000    0.000    0.000    0.000 socket.py:543(send)
#        20    0.001    0.000    0.014    0.001 string.py:115(_join_multiline)
#        20    0.000    0.000    0.000    0.000 string.py:122(<listcomp>)
#        20    0.001    0.000    0.004    0.000 string.py:124(<listcomp>)
#       220    0.001    0.000    0.002    0.000 string.py:125(<listcomp>)
#        20    0.000    0.000    0.000    0.000 string.py:18(__init__)
#        20    0.000    0.000    0.000    0.000 string.py:190(_binify)
#        20    0.000    0.000    0.185    0.009 string.py:24(to_string)
#        20    0.000    0.000    0.169    0.008 string.py:30(_get_strcols)
#        20    0.000    0.000    0.184    0.009 string.py:36(_get_string_representation)
#        20    0.000    0.000    0.000    0.000 string.py:59(_need_to_wrap_around)
#        60    0.001    0.000    0.001    0.000 take.py:120(_take_nd_ndarray)
#        60    0.000    0.000    0.000    0.000 take.py:326(_get_take_nd_function)
#        60    0.000    0.000    0.000    0.000 take.py:554(_take_preprocess_indexer_and_fill_value)
#        60    0.000    0.000    0.002    0.000 take.py:57(take_nd)
#         1    0.000    0.000    0.000    0.000 threading.py:1066(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 threading.py:1133(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:536(is_set)
#        80    0.000    0.000    0.000    0.000 types.py:171(__get__)
#      6600    0.005    0.000    0.005    0.000 typing.py:1375(cast)
#       260    0.001    0.000    0.114    0.000 util.py:159(atleast_2d_column_default)
#        20    0.000    0.000    0.000    0.000 util.py:556(safe_scalar_isnan)
#        20    0.000    0.000    0.000    0.000 util.py:583(iterable)
#       360    0.001    0.000    0.007    0.000 util.py:669(safe_is_pandas_categorical_dtype)
#        20    0.000    0.000    0.001    0.000 util.py:675(safe_is_pandas_categorical)
#       340    0.001    0.000    0.010    0.000 util.py:707(safe_issubdtype)
#        20    0.000    0.000    0.000    0.000 utils.py:249(maybe_convert_indices)
#        20    0.000    0.000    0.000    0.000 utils.py:457(check_array_indexer)
#       480    0.001    0.000    0.001    0.000 utils.py:69(is_list_like_indexer)
#        80    0.001    0.000    0.002    0.000 warnings.py:130(filterwarnings)
#        80    0.000    0.000    0.001    0.000 warnings.py:181(_add_filter)
#       120    0.000    0.000    0.000    0.000 warnings.py:437(__init__)
#       120    0.000    0.000    0.000    0.000 warnings.py:458(__enter__)
#       120    0.000    0.000    0.000    0.000 warnings.py:477(__exit__)
#     40/20    0.000    0.000    0.000    0.000 wrapper.py:21(__getattribute__)
#        80    0.000    0.000    0.000    0.000 wrapper.py:22(<lambda>)

# %% [markdown]
# As can be seen, the majority of the fuction call is spent on fectching the getattribute and length functions both of which are library functions. So, it would seem that this code is optimized. If profiling showed another custom defined function to be consuming the largest memory, then we might want to redefine those particular ones.

# %%
# %timeit predict(10)
# Out:
# 55.7 ms ± 1.07 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
cProfile.run('predict(10)')
# Out:
#          271945 function calls (267325 primitive calls) in 0.132 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.132    0.132 2983308015.py:2(predict)
#       110    0.000    0.000    0.010    0.000 <__array_function__ internals>:2(any)
#        10    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(argsort)
#        10    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(array_equal)
#        40    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(atleast_1d)
#        20    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(atleast_2d)
#        20    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(concatenate)
#       190    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(copyto)
#        10    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(dot)
#        10    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(repeat)
#        10    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(vstack)
#       930    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:1033(_handle_fromlist)
#       100    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#       110    0.000    0.000    0.000    0.000 __init__.py:152(align_method_SERIES)
#       100    0.000    0.000    0.004    0.000 __init__.py:207(align_method_FRAME)
#       100    0.000    0.000    0.000    0.000 __init__.py:315(should_reindex_frame_op)
#       110    0.000    0.000    0.000    0.000 _asarray.py:111(<setcomp>)
#       110    0.000    0.000    0.001    0.000 _asarray.py:22(require)
#        10    0.000    0.000    0.000    0.000 _dtype.py:178(_datetime_metadata_str)
#      2230    0.000    0.000    0.000    0.000 _dtype.py:24(_kind_name)
#      2230    0.000    0.000    0.000    0.000 _dtype.py:307(_name_includes_bit_suffix)
#      2230    0.002    0.000    0.002    0.000 _dtype.py:321(_name_get)
#        10    0.000    0.000    0.000    0.000 _methods.py:38(_amax)
#        10    0.000    0.000    0.000    0.000 _methods.py:46(_sum)
#       120    0.000    0.000    0.000    0.000 _methods.py:54(_any)
#       110    0.000    0.000    0.000    0.000 _methods.py:60(_all)
#        10    0.000    0.000    0.001    0.000 _mixins.py:266(__getitem__)
#       220    0.000    0.000    0.000    0.000 _ufunc_config.py:131(geterr)
#       220    0.000    0.000    0.001    0.000 _ufunc_config.py:32(seterr)
#       110    0.000    0.000    0.000    0.000 _ufunc_config.py:425(__init__)
#       110    0.000    0.000    0.001    0.000 _ufunc_config.py:429(__enter__)
#       110    0.000    0.000    0.000    0.000 _ufunc_config.py:434(__exit__)
#       100    0.000    0.000    0.000    0.000 _validators.py:122(_check_for_invalid_keys)
#       100    0.000    0.000    0.000    0.000 _validators.py:135(validate_kwargs)
#       100    0.000    0.000    0.000    0.000 _validators.py:218(validate_bool_kwarg)
#       100    0.000    0.000    0.000    0.000 _validators.py:43(_check_for_default_values)
#       240    0.000    0.000    0.000    0.000 abc.py:117(__instancecheck__)
#        10    0.000    0.000    0.000    0.000 abc.py:121(__subclasscheck__)
#        20    0.000    0.000    0.000    0.000 algorithms.py:1356(take)
#       110    0.000    0.000    0.000    0.000 api.py:177(union_indexes)
#        10    0.000    0.000    0.000    0.000 array_ops.py:134(_na_arithmetic_op)
#        10    0.000    0.000    0.000    0.000 array_ops.py:227(comparison_op)
#       210    0.000    0.000    0.000    0.000 array_ops.py:291(na_logical_op)
#       210    0.001    0.000    0.003    0.000 array_ops.py:332(logical_op)
#       420    0.000    0.000    0.001    0.000 array_ops.py:350(fill_bool)
#       100    0.000    0.000    0.000    0.000 array_ops.py:398(get_array_op)
#       100    0.000    0.000    0.000    0.000 array_ops.py:441(maybe_prepare_scalar_for_op)
#       320    0.001    0.000    0.001    0.000 arraylike.py:180(_maybe_fallback)
#       860    0.000    0.000    0.000    0.000 arraylike.py:193(<genexpr>)
#       860    0.000    0.000    0.000    0.000 arraylike.py:194(<genexpr>)
#   320/210    0.002    0.000    0.026    0.000 arraylike.py:242(array_ufunc)
#       530    0.000    0.000    0.000    0.000 arraylike.py:284(<genexpr>)
#       210    0.000    0.000    0.000    0.000 arraylike.py:285(<listcomp>)
#        10    0.000    0.000    0.000    0.000 arraylike.py:317(<listcomp>)
#       210    0.000    0.000    0.005    0.000 arraylike.py:323(reconstruct)
#       210    0.001    0.000    0.005    0.000 arraylike.py:330(_reconstruct)
#        10    0.000    0.000    0.001    0.000 arraylike.py:38(__eq__)
#       320    0.000    0.000    0.000    0.000 arraylike.py:416(_standardize_out_kwarg)
#       110    0.000    0.000    0.016    0.000 arraylike.py:431(dispatch_ufunc_with_out)
#       110    0.000    0.000    0.001    0.000 arraylike.py:466(_assign_where)
#       100    0.000    0.000    0.006    0.000 arraylike.py:76(__or__)
#       110    0.000    0.000    0.013    0.000 arraylike.py:80(__ror__)
#        20    0.000    0.000    0.000    0.000 base.py:1106(take)
#        20    0.000    0.000    0.000    0.000 base.py:1132(_maybe_disallow_fill)
#        40    0.000    0.000    0.000    0.000 base.py:1658(name)
#        10    0.000    0.000    0.000    0.000 base.py:1906(nlevels)
#        10    0.000    0.000    0.001    0.000 base.py:210(interleaved_dtype)
#        10    0.000    0.000    0.000    0.000 base.py:2240(is_unique)
#        40    0.000    0.000    0.000    0.000 base.py:2280(is_boolean)
#       150    0.000    0.000    0.000    0.000 base.py:229(disallow_kwargs)
#       110    0.000    0.000    0.000    0.000 base.py:2352(is_floating)
#        20    0.000    0.000    0.000    0.000 base.py:2440(is_object)
#        30    0.000    0.000    0.000    0.000 base.py:2604(inferred_type)
#        40    0.000    0.000    0.000    0.000 base.py:2632(_is_multi)
#       430    0.000    0.000    0.001    0.000 base.py:286(is_dtype)
#        10    0.000    0.000    0.000    0.000 base.py:315(shape)
#       160    0.000    0.000    0.000    0.000 base.py:326(ndim)
#        10    0.000    0.000    0.000    0.000 base.py:358(size)
#       110    0.000    0.000    0.000    0.000 base.py:3585(get_loc)
#        20    0.000    0.000    0.002    0.000 base.py:3714(get_indexer)
#        20    0.000    0.000    0.000    0.000 base.py:3794(_get_indexer)
#        20    0.000    0.000    0.000    0.000 base.py:3837(_check_indexing_method)
#   280/150    0.002    0.000    0.010    0.000 base.py:397(__new__)
#        10    0.000    0.000    0.001    0.000 base.py:4123(reindex)
#        10    0.000    0.000    0.000    0.000 base.py:4240(_wrap_reindex_result)
#        10    0.000    0.000    0.000    0.000 base.py:4244(_maybe_preserve_names)
#        40    0.000    0.000    0.000    0.000 base.py:45(__len__)
#        30    0.000    0.000    0.000    0.000 base.py:465(find)
#       370    0.000    0.000    0.000    0.000 base.py:4834(_values)
#        50    0.000    0.000    0.000    0.000 base.py:4860(_get_engine_target)
#       130    0.000    0.000    0.000    0.000 base.py:4987(__contains__)
#       230    0.000    0.000    0.000    0.000 base.py:5037(__getitem__)
#        20    0.000    0.000    0.000    0.000 base.py:5092(_can_hold_identifiers_and_holds_name)
#       220    0.000    0.000    0.000    0.000 base.py:518(<genexpr>)
#       740    0.000    0.000    0.001    0.000 base.py:5192(equals)
#       150    0.000    0.000    0.000    0.000 base.py:53(shape)
#       140    0.000    0.000    0.000    0.000 base.py:540(_ensure_array)
#       450    0.000    0.000    0.000    0.000 base.py:55(<genexpr>)
#       150    0.000    0.000    0.001    0.000 base.py:554(_dtype_to_subclass)
#       200    0.000    0.000    0.000    0.000 base.py:57(_validate_set_axis)
#        10    0.000    0.000    0.002    0.000 base.py:5758(get_indexer_for)
#        10    0.000    0.000    0.003    0.000 base.py:5782(_get_indexer_strict)
#        10    0.000    0.000    0.000    0.000 base.py:5813(_raise_if_missing)
#        50    0.000    0.000    0.000    0.000 base.py:5919(_index_as_unique)
#        20    0.000    0.000    0.000    0.000 base.py:5931(_maybe_promote)
#        20    0.000    0.000    0.000    0.000 base.py:6018(_should_compare)
#        20    0.000    0.000    0.000    0.000 base.py:6036(_is_comparable_dtype)
#       110    0.000    0.000    0.000    0.000 base.py:6298(_maybe_cast_indexer)
#        20    0.000    0.000    0.001    0.000 base.py:6307(_maybe_cast_listlike_indexer)
#       180    0.000    0.000    0.000    0.000 base.py:654(_simple_new)
#        40    0.000    0.000    0.003    0.000 base.py:672(_with_infer)
#        10    0.000    0.000    0.000    0.000 base.py:692(_constructor)
#      1180    0.000    0.000    0.004    0.000 base.py:7004(ensure_index)
#        10    0.000    0.000    0.000    0.000 base.py:7063(ensure_has_len)
#       550    0.000    0.000    0.001    0.000 base.py:7099(maybe_extract_name)
#       150    0.000    0.000    0.003    0.000 base.py:7123(_maybe_cast_data_without_dtype)
#        20    0.000    0.000    0.000    0.000 base.py:7185(unpack_nested_dtype)
#        30    0.000    0.000    0.000    0.000 base.py:744(__iter__)
#       740    0.000    0.000    0.000    0.000 base.py:803(is_)
#       180    0.000    0.000    0.000    0.000 base.py:834(_reset_identity)
#        30    0.000    0.000    0.000    0.000 base.py:845(_engine)
#      3760    0.001    0.000    0.001    0.000 base.py:884(__len__)
#        60    0.000    0.000    0.000    0.000 base.py:945(dtype)
#        10    0.000    0.000    0.000    0.000 blocks.py:1116(take_nd)
#      2190    0.002    0.000    0.004    0.000 blocks.py:166(_consolidate_key)
#      2920    0.002    0.000    0.003    0.000 blocks.py:1962(maybe_coerce_values)
#      3020    0.002    0.000    0.003    0.000 blocks.py:1991(get_block_type)
#      2420    0.001    0.000    0.006    0.000 blocks.py:2032(new_block_2d)
#       490    0.001    0.000    0.003    0.000 blocks.py:2043(new_block)
#       490    0.000    0.000    0.001    0.000 blocks.py:2057(check_ndim)
#       140    0.000    0.000    0.000    0.000 blocks.py:2121(extend_blocks)
#      2190    0.001    0.000    0.002    0.000 blocks.py:2137(ensure_block_shape)
#       100    0.000    0.000    0.000    0.000 blocks.py:222(get_values)
#        10    0.000    0.000    0.000    0.000 blocks.py:238(fill_value)
#      2640    0.000    0.000    0.000    0.000 blocks.py:244(mgr_locs)
#       100    0.000    0.000    0.000    0.000 blocks.py:248(mgr_locs)
#       220    0.000    0.000    0.001    0.000 blocks.py:252(make_block)
#        10    0.000    0.000    0.000    0.000 blocks.py:267(make_block_same_class)
#       100    0.000    0.000    0.000    0.000 blocks.py:310(_slice)
#       100    0.000    0.000    0.000    0.000 blocks.py:332(getitem_block_columns)
#        20    0.000    0.000    0.000    0.000 blocks.py:350(shape)
#      2440    0.000    0.000    0.000    0.000 blocks.py:354(dtype)
#      2300    0.013    0.000    0.013    0.000 blocks.py:358(iget)
#       110    0.000    0.000    0.001    0.000 blocks.py:396(apply)
#       210    0.000    0.000    0.001    0.000 blocks.py:427(_split_op_result)
#        10    0.000    0.000    0.000    0.000 blocks.py:560(astype)
#       240    0.000    0.000    0.000    0.000 build.py:207(_column_combinations)
#       120    0.000    0.000    0.000    0.000 build.py:209(<listcomp>)
#       120    0.000    0.000    0.000    0.000 build.py:223(_subterm_column_combinations)
#       120    0.001    0.000    0.001    0.000 build.py:259(_build_subterm)
#        10    0.000    0.000    0.000    0.000 build.py:347(_factors_memorize)
#       100    0.000    0.000    0.000    0.000 build.py:42(_max_allowed_dim)
#        10    0.000    0.000    0.000    0.000 build.py:437(_examine_factor_types)
#        10    0.000    0.000    0.000    0.000 build.py:571(_make_subterm_infos)
#       110    0.000    0.000    0.057    0.001 build.py:61(_eval_factor)
#        10    0.000    0.000    0.000    0.000 build.py:638(design_matrix_builders)
#        20    0.000    0.000    0.003    0.000 build.py:739(_build_design_matrix)
#        20    0.000    0.000    0.000    0.000 build.py:775(__init__)
#       240    0.000    0.000    0.000    0.000 build.py:782(check)
#        10    0.001    0.000    0.076    0.008 build.py:797(build_design_matrices)
#       110    0.000    0.000    0.000    0.000 build.py:877(<lambda>)
#       110    0.000    0.000    0.000    0.000 build.py:878(<lambda>)
#        10    0.000    0.000    0.000    0.000 build.py:908(<listcomp>)
#     20/10    0.000    0.000    0.000    0.000 cast.py:1075(astype_nansafe)
#        10    0.000    0.000    0.000    0.000 cast.py:1199(astype_array)
#        10    0.000    0.000    0.000    0.000 cast.py:1246(astype_array_safe)
#      2190    0.003    0.000    0.005    0.000 cast.py:1466(maybe_infer_to_datetimelike)
#        10    0.000    0.000    0.001    0.000 cast.py:1499(try_datetime)
#       250    0.000    0.000    0.000    0.000 cast.py:1711(sanitize_to_nanoseconds)
#        10    0.000    0.000    0.001    0.000 cast.py:1789(find_common_type)
#        70    0.000    0.000    0.000    0.000 cast.py:1819(<genexpr>)
#        20    0.000    0.000    0.000    0.000 cast.py:1828(<genexpr>)
#        20    0.000    0.000    0.000    0.000 cast.py:1830(<genexpr>)
#        20    0.000    0.000    0.000    0.000 cast.py:1835(<genexpr>)
#       130    0.000    0.000    0.000    0.000 cast.py:1962(construct_1d_object_array_from_listlike)
#        10    0.000    0.000    0.000    0.000 cast.py:1987(maybe_cast_to_integer_array)
#        20    0.000    0.000    0.000    0.000 cast.py:468(maybe_promote)
#        10    0.000    0.000    0.000    0.000 categorical.py:151(_categorical_shape_fix)
#        10    0.000    0.000    0.001    0.000 categorical.py:308(categorical_to_int)
#        10    0.000    0.000    0.000    0.000 common.py:1042(is_numeric_v_string_like)
#        50    0.000    0.000    0.000    0.000 common.py:105(is_bool_indexer)
#       310    0.000    0.000    0.000    0.000 common.py:1148(needs_i8_conversion)
#       350    0.000    0.000    0.001    0.000 common.py:1240(is_float_dtype)
#       440    0.000    0.000    0.001    0.000 common.py:1274(is_bool_dtype)
#      3260    0.001    0.000    0.001    0.000 common.py:1416(is_1d_only_ea_dtype)
#       290    0.000    0.000    0.000    0.000 common.py:1429(is_extension_array_dtype)
#      1010    0.000    0.000    0.000    0.000 common.py:145(classes)
#      1010    0.000    0.000    0.000    0.000 common.py:147(<lambda>)
#       560    0.000    0.000    0.000    0.000 common.py:1483(is_ea_or_datetimelike_dtype)
#        20    0.000    0.000    0.000    0.000 common.py:1496(is_complex_dtype)
#       890    0.000    0.000    0.000    0.000 common.py:150(classes_and_not_datetimelike)
#       890    0.000    0.000    0.000    0.000 common.py:155(<lambda>)
#       780    0.000    0.000    0.000    0.000 common.py:1552(get_dtype)
#      1900    0.001    0.000    0.002    0.000 common.py:1587(_is_dtype_type)
#       330    0.000    0.000    0.000    0.000 common.py:160(cast_scalar_indexer)
#       630    0.000    0.000    0.001    0.000 common.py:161(is_object_dtype)
#       540    0.000    0.000    0.001    0.000 common.py:1721(validate_all_hashable)
#      1080    0.000    0.000    0.000    0.000 common.py:1740(<genexpr>)
#       280    0.000    0.000    0.000    0.000 common.py:1747(pandas_dtype)
#       280    0.000    0.000    0.001    0.000 common.py:229(asarray_tuplesafe)
#       110    0.000    0.000    0.000    0.000 common.py:287(maybe_iterable_to_list)
#        10    0.000    0.000    0.000    0.000 common.py:297(is_null_slice)
#        40    0.000    0.000    0.000    0.000 common.py:315(is_datetime64_dtype)
#       140    0.000    0.000    0.000    0.000 common.py:346(apply_if_callable)
#       130    0.000    0.000    0.000    0.000 common.py:348(is_datetime64tz_dtype)
#        30    0.000    0.000    0.000    0.000 common.py:389(is_timedelta64_dtype)
#        10    0.000    0.000    0.000    0.000 common.py:423(is_period_dtype)
#        20    0.000    0.000    0.000    0.000 common.py:459(is_interval_dtype)
#       270    0.000    0.000    0.001    0.000 common.py:497(is_categorical_dtype)
#       100    0.000    0.000    0.000    0.000 common.py:533(is_string_or_object_np_dtype)
#       220    0.000    0.000    0.021    0.000 common.py:55(new_method)
#       270    0.000    0.000    0.000    0.000 common.py:552(require_length_match)
#       170    0.000    0.000    0.000    0.000 common.py:581(is_dtype_equal)
#       580    0.000    0.000    0.001    0.000 common.py:680(is_integer_dtype)
#       160    0.000    0.000    0.000    0.000 common.py:732(is_signed_integer_dtype)
#       120    0.000    0.000    0.000    0.000 common.py:75(get_op_result_name)
#       150    0.000    0.000    0.000    0.000 common.py:786(is_unsigned_integer_dtype)
#        90    0.000    0.000    0.000    0.000 common.py:97(_maybe_match_name)
#       110    0.000    0.000    0.005    0.000 compat.py:34(call_and_wrap_exc)
#       610    0.001    0.000    0.002    0.000 config.py:109(_get_single_key)
#       610    0.000    0.000    0.003    0.000 config.py:127(_get_option)
#       610    0.000    0.000    0.003    0.000 config.py:255(__call__)
#       610    0.000    0.000    0.000    0.000 config.py:571(_select_options)
#       610    0.000    0.000    0.001    0.000 config.py:589(_get_root)
#      1220    0.000    0.000    0.000    0.000 config.py:603(_get_deprecated_option)
#       610    0.000    0.000    0.000    0.000 config.py:630(_translate_key)
#       610    0.000    0.000    0.000    0.000 config.py:642(_warn_if_deprecated)
#       110    0.000    0.000    0.003    0.000 construction.py:102(arrays_to_mgr)
#       340    0.000    0.000    0.000    0.000 construction.py:233(mgr_to_mgr)
#       230    0.001    0.000    0.032    0.000 construction.py:274(ndarray_to_mgr)
#       640    0.000    0.000    0.001    0.000 construction.py:379(extract_array)
#        10    0.001    0.000    0.006    0.001 construction.py:382(<listcomp>)
#        40    0.000    0.000    0.000    0.000 construction.py:384(<genexpr>)
#        10    0.000    0.000    0.003    0.000 construction.py:385(<listcomp>)
#        10    0.001    0.000    0.006    0.001 construction.py:386(<listcomp>)
#       230    0.000    0.000    0.000    0.000 construction.py:407(_check_values_indices_shape_match)
#       110    0.000    0.000    0.013    0.000 construction.py:425(dict_to_mgr)
#      3430    0.001    0.000    0.001    0.000 construction.py:438(ensure_wrapped_if_datetimelike)
#       400    0.001    0.000    0.004    0.000 construction.py:470(sanitize_array)
#       110    0.000    0.000    0.000    0.000 construction.py:483(<listcomp>)
#       110    0.000    0.000    0.000    0.000 construction.py:486(<listcomp>)
#       110    0.000    0.000    0.000    0.000 construction.py:487(<listcomp>)
#       110    0.000    0.000    0.000    0.000 construction.py:494(<listcomp>)
#       230    0.000    0.000    0.000    0.000 construction.py:549(_prep_ndarray)
#       110    0.000    0.000    0.000    0.000 construction.py:596(_homogenize)
#       400    0.000    0.000    0.001    0.000 construction.py:630(_sanitize_ndim)
#       110    0.000    0.000    0.000    0.000 construction.py:635(_extract_index)
#       400    0.000    0.000    0.000    0.000 construction.py:667(_sanitize_str_dtypes)
#       400    0.000    0.000    0.000    0.000 construction.py:687(_maybe_repeat)
#       400    0.000    0.000    0.001    0.000 construction.py:698(_try_cast)
#       230    0.000    0.000    0.002    0.000 construction.py:747(_get_axes)
#       270    0.000    0.000    0.000    0.000 construction.py:805(is_empty_data)
#        10    0.000    0.000    0.000    0.000 contextlib.py:376(__init__)
#        10    0.000    0.000    0.000    0.000 contextlib.py:379(__enter__)
#        10    0.000    0.000    0.000    0.000 contextlib.py:382(__exit__)
#        10    0.000    0.000    0.000    0.000 data.py:94(_is_using_pandas)
#        10    0.000    0.000    0.001    0.000 datetimelike.py:330(__getitem__)
#        20    0.000    0.000    0.000    0.000 datetimelike.py:880(freq)
#        10    0.000    0.000    0.001    0.000 datetimes.py:2004(sequence_to_datetimes)
#        10    0.000    0.000    0.001    0.000 datetimes.py:2019(_sequence_to_dt64ns)
#        10    0.000    0.000    0.000    0.000 datetimes.py:2176(objects_to_datetime64ns)
#        10    0.000    0.000    0.000    0.000 datetimes.py:2268(maybe_convert_dtype)
#        10    0.000    0.000    0.000    0.000 datetimes.py:2359(_validate_dt64_dtype)
#        20    0.000    0.000    0.000    0.000 datetimes.py:2401(validate_tz_from_dtype)
#        10    0.000    0.000    0.000    0.000 datetimes.py:326(_simple_new)
#        10    0.001    0.000    0.001    0.000 datetimes.py:530(_box_func)
#        50    0.000    0.000    0.000    0.000 datetimes.py:545(dtype)
#        10    0.000    0.000    0.000    0.000 datetimes.py:570(tz)
#        10    0.000    0.000    0.000    0.000 datetimes.py:96(tz_to_dtype)
#       240    0.000    0.000    0.000    0.000 desc.py:53(__hash__)
#        30    0.000    0.000    0.001    0.000 design_info.py:1014(__new__)
#        10    0.000    0.000    0.000    0.000 design_info.py:271(__init__)
#        10    0.000    0.000    0.000    0.000 design_info.py:361(<listcomp>)
#        80    0.000    0.000    0.000    0.000 design_info.py:401(column_names)
#       220    0.000    0.000    0.000    0.000 dispatch.py:11(should_extension_dispatch)
#        20    0.000    0.000    0.000    0.000 dtypes.py:1206(is_dtype)
#        10    0.000    0.000    0.000    0.000 dtypes.py:955(is_dtype)
#        40    0.000    0.000    0.000    0.000 enum.py:792(value)
#        10    0.000    0.000    0.000    0.000 eval.py:136(__init__)
#       110    0.000    0.000    0.005    0.000 eval.py:155(eval)
#        20    0.000    0.000    0.000    0.000 eval.py:168(capture)
#       220    0.000    0.000    0.000    0.000 eval.py:42(__init__)
#   220/110    0.000    0.000    0.004    0.000 eval.py:45(__getitem__)
#       110    0.000    0.000    0.000    0.000 eval.py:451(name)
#      1310    0.000    0.000    0.000    0.000 eval.py:464(__hash__)
#       110    0.000    0.000    0.005    0.000 eval.py:545(_eval)
#       110    0.000    0.000    0.005    0.000 eval.py:563(eval)
#        10    0.000    0.000    0.000    0.000 expressions.py:223(evaluate)
#        10    0.000    0.000    0.000    0.000 expressions.py:63(_evaluate_standard)
#        10    0.000    0.000    0.000    0.000 expressions.py:72(_can_use_numexpr)
#        10    0.000    0.000    0.000    0.000 expressions.py:92(_evaluate_numexpr)
#      1050    0.000    0.000    0.000    0.000 flags.py:47(__init__)
#       480    0.000    0.000    0.000    0.000 flags.py:51(allows_duplicate_labels)
#       480    0.000    0.000    0.000    0.000 flags.py:83(allows_duplicate_labels)
#       100    0.000    0.000    0.000    0.000 frame.py:10314(_get_agg_axis)
#       100    0.000    0.000    0.001    0.000 frame.py:10817(values)
#        30    0.000    0.000    0.000    0.000 frame.py:1413(__len__)
#        10    0.000    0.000    0.028    0.003 frame.py:3273(transpose)
#        10    0.000    0.000    0.028    0.003 frame.py:3404(T)
#       120    0.000    0.000    0.018    0.000 frame.py:3411(_ixs)
#       120    0.000    0.000    0.009    0.000 frame.py:3463(__getitem__)
#       110    0.000    0.000    0.001    0.000 frame.py:3906(_box_col_values)
#       200    0.000    0.000    0.000    0.000 frame.py:3920(_clear_item_cache)
#       110    0.000    0.000    0.003    0.000 frame.py:3923(_get_item_cache)
#       530    0.000    0.000    0.000    0.000 frame.py:578(_constructor)
#       660    0.002    0.000    0.050    0.000 frame.py:587(__init__)
#       100    0.000    0.000    0.012    0.000 frame.py:6946(_arith_method)
#       100    0.001    0.000    0.006    0.000 frame.py:6960(_dispatch_frame_op)
#       100    0.000    0.000    0.001    0.000 frame.py:7055(_construct_result)
#       210    0.000    0.000    0.000    0.000 frame.py:804(axes)
#       520    0.000    0.000    0.001    0.000 frame.py:821(shape)
#        10    0.000    0.000    0.000    0.000 frame.py:881(_can_fast_transpose)
#       320    0.001    0.000    0.002    0.000 frame.py:898(_values)
#       100    0.001    0.000    0.008    0.000 frame.py:9940(_reduce)
#       100    0.000    0.000    0.002    0.000 frame.py:9983(func)
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:1002(_argsort_dispatcher)
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:1006(argsort)
#       110    0.000    0.000    0.000    0.000 fromnumeric.py:2263(_any_dispatcher)
#       110    0.000    0.000    0.010    0.000 fromnumeric.py:2268(any)
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:432(_repeat_dispatcher)
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:436(repeat)
#        20    0.000    0.000    0.000    0.000 fromnumeric.py:51(_wrapfunc)
#       110    0.000    0.000    0.010    0.000 fromnumeric.py:69(_wrapreduction)
#       110    0.000    0.000    0.000    0.000 fromnumeric.py:70(<dictcomp>)
#       120    0.000    0.000    0.000    0.000 function.py:49(__call__)
#       100    0.000    0.000    0.009    0.000 generic.py:10400(_logical_func)
#       100    0.000    0.000    0.009    0.000 generic.py:10458(any)
#       100    0.000    0.000    0.009    0.000 generic.py:10880(any)
#       100    0.000    0.000    0.008    0.000 generic.py:11344(_inplace_method)
#       100    0.000    0.000    0.008    0.000 generic.py:11406(__ior__)
#       200    0.000    0.000    0.001    0.000 generic.py:1399(_indexed_same)
#       500    0.000    0.000    0.001    0.000 generic.py:1401(<genexpr>)
#        10    0.000    0.000    0.000    0.000 generic.py:1516(__invert__)
#       310    0.000    0.000    0.002    0.000 generic.py:2063(__array__)
#   320/210    0.000    0.000    0.027    0.000 generic.py:2097(__array_ufunc__)
#      1050    0.001    0.000    0.002    0.000 generic.py:239(__init__)
#       480    0.000    0.000    0.000    0.000 generic.py:328(attrs)
#       960    0.000    0.000    0.000    0.000 generic.py:349(flags)
#        10    0.000    0.000    0.001    0.000 generic.py:3609(take)
#        10    0.000    0.000    0.002    0.000 generic.py:3708(_take_with_is_copy)
#        20    0.000    0.000    0.000    0.000 generic.py:3925(_set_is_copy)
#      7060    0.001    0.000    0.002    0.000 generic.py:43(_check)
#        20    0.000    0.000    0.000    0.000 generic.py:441(_validate_dtype)
#       760    0.000    0.000    0.000    0.000 generic.py:546(_get_axis_number)
#       480    0.001    0.000    0.002    0.000 generic.py:5517(__finalize__)
#      1220    0.001    0.000    0.001    0.000 generic.py:5561(__getattr__)
#      1290    0.001    0.000    0.003    0.000 generic.py:5577(__setattr__)
#       650    0.000    0.000    0.000    0.000 generic.py:560(_get_axis)
#       430    0.000    0.000    0.001    0.000 generic.py:5632(_protect_consolidate)
#       430    0.000    0.000    0.001    0.000 generic.py:5646(_consolidate_inplace)
#       430    0.000    0.000    0.001    0.000 generic.py:5650(f)
#        10    0.000    0.000    0.000    0.000 generic.py:566(_get_block_manager_axis)
#        10    0.000    0.000    0.001    0.000 generic.py:5718(dtypes)
#        10    0.000    0.000    0.001    0.000 generic.py:5749(astype)
#        30    0.000    0.000    0.000    0.000 generic.py:636(_info_axis)
#      1220    0.000    0.000    0.000    0.000 generic.py:660(ndim)
#       200    0.000    0.000    0.001    0.000 generic.py:767(_set_axis)
#        10    0.000    0.000    0.076    0.008 highlevel.py:154(_do_highlevel_design)
#        10    0.000    0.000    0.000    0.000 highlevel.py:162(data_iter_maker)
#        10    0.000    0.000    0.077    0.008 highlevel.py:225(dmatrix)
#        10    0.000    0.000    0.000    0.000 highlevel.py:33(_try_incr_builders)
#        10    0.000    0.000    0.000    0.000 indexing.py:130(iloc)
#        20    0.000    0.000    0.000    0.000 indexing.py:1346(_validate_key)
#        10    0.000    0.000    0.000    0.000 indexing.py:1422(_is_scalar_access)
#        30    0.000    0.000    0.000    0.000 indexing.py:1435(<genexpr>)
#        20    0.000    0.000    0.000    0.000 indexing.py:1437(_validate_integer)
#        10    0.000    0.000    0.017    0.002 indexing.py:1459(_getitem_tuple)
#        10    0.000    0.000    0.016    0.002 indexing.py:1490(_getitem_axis)
#        10    0.000    0.000    0.000    0.000 indexing.py:2323(convert_to_index_sliceable)
#        10    0.000    0.000    0.000    0.000 indexing.py:2459(is_label_like)
#       130    0.000    0.000    0.000    0.000 indexing.py:2486(check_deprecated_indexers)
#        30    0.000    0.000    0.000    0.000 indexing.py:2491(<genexpr>)
#        30    0.000    0.000    0.000    0.000 indexing.py:2502(<genexpr>)
#        10    0.000    0.000    0.000    0.000 indexing.py:740(_expand_ellipsis)
#        30    0.000    0.000    0.000    0.000 indexing.py:745(<genexpr>)
#        10    0.000    0.000    0.000    0.000 indexing.py:761(_validate_tuple_indexer)
#        10    0.000    0.000    0.000    0.000 indexing.py:777(_is_nested_tuple_indexer)
#        30    0.000    0.000    0.000    0.000 indexing.py:783(<genexpr>)
#        20    0.000    0.000    0.000    0.000 indexing.py:804(_validate_key_length)
#        10    0.000    0.000    0.017    0.002 indexing.py:834(_getitem_lowerdim)
#        10    0.000    0.000    0.017    0.002 indexing.py:954(__getitem__)
#        30    0.000    0.000    0.000    0.000 indexing.py:957(<genexpr>)
#        30    0.000    0.000    0.000    0.000 indexing.py:958(<genexpr>)
#        70    0.000    0.000    0.000    0.000 inference.py:184(is_array_like)
#        10    0.000    0.000    0.000    0.000 inference.py:262(is_dict_like)
#        20    0.000    0.000    0.000    0.000 inference.py:288(<genexpr>)
#      1230    0.000    0.000    0.000    0.000 inference.py:321(is_hashable)
#        10    0.000    0.000    0.000    0.000 inspect.py:1548(currentframe)
#        10    0.000    0.000    0.000    0.000 inspect.py:73(isclass)
#        10    0.000    0.000    0.000    0.000 linear_model.py:355(predict)
#       110    0.000    0.000    0.001    0.000 managers.py:1026(iget)
#       100    0.000    0.000    0.004    0.000 managers.py:1415(operate_blockwise)
#       100    0.000    0.000    0.000    0.000 managers.py:1551(as_array)
#       130    0.000    0.000    0.000    0.000 managers.py:156(blknos)
#       770    0.000    0.000    0.002    0.000 managers.py:1675(is_consolidated)
#       440    0.000    0.000    0.002    0.000 managers.py:1683(_consolidate_check)
#        20    0.001    0.000    0.002    0.000 managers.py:1689(<listcomp>)
#       340    0.000    0.000    0.011    0.000 managers.py:1693(_consolidate_inplace)
#       390    0.000    0.000    0.000    0.000 managers.py:1714(__init__)
#       120    0.000    0.000    0.000    0.000 managers.py:172(blklocs)
#        10    0.000    0.000    0.000    0.000 managers.py:1736(from_blocks)
#       270    0.000    0.000    0.002    0.000 managers.py:1745(from_array)
#       380    0.000    0.000    0.000    0.000 managers.py:1806(_block)
#       680    0.000    0.000    0.001    0.000 managers.py:1851(dtype)
#       780    0.000    0.000    0.000    0.000 managers.py:1862(internal_values)
#       230    0.000    0.000    0.011    0.000 managers.py:1925(create_block_manager_from_blocks)
#       110    0.000    0.000    0.002    0.000 managers.py:1951(create_block_manager_from_column_arrays)
#       110    0.000    0.000    0.000    0.000 managers.py:2006(_grouping_func)
#       110    0.001    0.000    0.002    0.000 managers.py:2022(_form_blocks)
#       110    0.000    0.000    0.000    0.000 managers.py:2074(_stack_arrays)
#        10    0.000    0.000    0.009    0.001 managers.py:2088(_consolidate)
#      4380    0.001    0.000    0.005    0.000 managers.py:2093(<lambda>)
#        20    0.000    0.000    0.003    0.000 managers.py:2105(_merge_blocks)
#        10    0.001    0.000    0.001    0.000 managers.py:2116(<listcomp>)
#       200    0.000    0.000    0.001    0.000 managers.py:212(set_axis)
#        10    0.000    0.000    0.000    0.000 managers.py:2125(<listcomp>)
#       110    0.000    0.000    0.000    0.000 managers.py:2151(_preprocess_slice_or_indexer)
#       210    0.000    0.000    0.000    0.000 managers.py:217(is_single_block)
#       140    0.000    0.000    0.000    0.000 managers.py:222(items)
#        10    0.000    0.000    0.000    0.000 managers.py:226(get_dtypes)
#        10    0.000    0.000    0.000    0.000 managers.py:227(<listcomp>)
#       100    0.000    0.000    0.000    0.000 managers.py:230(arrays)
#       100    0.000    0.000    0.000    0.000 managers.py:239(<listcomp>)
#       120    0.000    0.000    0.002    0.000 managers.py:253(apply)
#       120    0.000    0.000    0.000    0.000 managers.py:282(<dictcomp>)
#        10    0.000    0.000    0.001    0.000 managers.py:418(astype)
#       430    0.000    0.000    0.000    0.000 managers.py:618(consolidate)
#        10    0.000    0.000    0.001    0.000 managers.py:634(reindex_indexer)
#       110    0.000    0.000    0.002    0.000 managers.py:710(_slice_take_blocks_ax0)
#        10    0.000    0.000    0.001    0.000 managers.py:872(take)
#       560    0.000    0.000    0.000    0.000 managers.py:916(__init__)
#       120    0.000    0.000    0.000    0.000 managers.py:970(from_blocks)
#        10    0.001    0.000    0.015    0.002 managers.py:980(fast_xs)
#        10    0.000    0.000    0.000    0.000 managers.py:995(<listcomp>)
#        20    0.000    0.000    0.000    0.000 missing.py:107(clean_fill_method)
#        10    0.000    0.000    0.000    0.000 missing.py:119(is_categorical_NA)
#       100    0.001    0.000    0.036    0.000 missing.py:129(is_numerical_NA)
#        10    0.000    0.000    0.000    0.000 missing.py:138(dispatch_fill_zeros)
#        10    0.000    0.000    0.011    0.001 missing.py:141(handle_NA)
#       110    0.000    0.000    0.000    0.000 missing.py:150(_isna)
#        10    0.000    0.000    0.011    0.001 missing.py:175(_handle_NA_drop)
#        10    0.000    0.000    0.001    0.000 missing.py:181(<listcomp>)
#       100    0.000    0.000    0.000    0.000 missing.py:227(_isna_array)
#       100    0.000    0.000    0.001    0.000 missing.py:288(notna)
#        40    0.000    0.000    0.000    0.000 missing.py:391(array_equivalent)
#        10    0.000    0.000    0.000    0.000 missing.py:572(na_value_for_dtype)
#       110    0.000    0.000    0.001    0.000 missing.py:67(isna)
#        20    0.000    0.000    0.000    0.000 missing.py:88(__init__)
#        20    0.000    0.000    0.000    0.000 missing.py:911(clean_reindex_fill_method)
#        10    0.000    0.000    0.078    0.008 model.py:1065(predict)
#       190    0.000    0.000    0.000    0.000 multiarray.py:1071(copyto)
#        20    0.000    0.000    0.000    0.000 multiarray.py:148(concatenate)
#        10    0.000    0.000    0.000    0.000 multiarray.py:736(dot)
#       100    0.000    0.000    0.000    0.000 nanops.py:191(_get_fill_value)
#       100    0.000    0.000    0.000    0.000 nanops.py:213(_maybe_get_mask)
#       100    0.000    0.000    0.001    0.000 nanops.py:257(_get_values)
#       100    0.000    0.000    0.000    0.000 nanops.py:346(_na_ok_dtype)
#       100    0.000    0.000    0.002    0.000 nanops.py:488(nanany)
#        10    0.000    0.000    0.000    0.000 numeric.py:139(_ensure_array)
#        10    0.000    0.000    0.000    0.000 numeric.py:188(_validate_dtype)
#        10    0.000    0.000    0.000    0.000 numeric.py:199(_ensure_dtype)
#        10    0.000    0.000    0.000    0.000 numeric.py:2381(_array_equal_dispatcher)
#        10    0.000    0.000    0.000    0.000 numeric.py:2385(array_equal)
#       190    0.000    0.000    0.001    0.000 numeric.py:289(full)
#       260    0.000    0.000    0.000    0.000 numeric.py:331(_is_all_dates)
#       400    0.000    0.000    0.000    0.000 numerictypes.py:284(issubclass_)
#       200    0.000    0.000    0.000    0.000 numerictypes.py:358(issubdtype)
#       100    0.000    0.000    0.000    0.000 ops.py:101(_get_same_shape_values)
#       200    0.000    0.000    0.001    0.000 ops.py:27(_iter_block_pairs)
#       100    0.000    0.000    0.004    0.000 ops.py:55(operate_blockwise)
#       100    0.000    0.000    0.000    0.000 ops.py:89(_reset_block_mgr_locs)
#        10    0.000    0.000    0.000    0.000 random.py:237(_randbelow_with_getrandbits)
#        10    0.000    0.000    0.000    0.000 random.py:290(randrange)
#        10    0.000    0.000    0.000    0.000 random.py:334(randint)
#        30    0.000    0.000    0.000    0.000 range.py:909(__len__)
#        10    0.000    0.000    0.000    0.000 range.py:919(__getitem__)
#        40    0.000    0.000    0.000    0.000 re.py:250(compile)
#        40    0.000    0.000    0.000    0.000 re.py:289(_compile)
#       110    0.000    0.000    0.000    0.000 roperator.py:55(ror_)
#       110    0.000    0.000    0.000    0.000 series.py:1238(_set_as_cached)
#       120    0.000    0.000    0.005    0.000 series.py:2988(_construct_result)
#       390    0.002    0.000    0.011    0.000 series.py:323(__init__)
#       140    0.000    0.000    0.000    0.000 series.py:523(_constructor)
#       270    0.000    0.000    0.000    0.000 series.py:542(_set_axis)
#        10    0.000    0.000    0.001    0.000 series.py:5613(_cmp_method)
#       110    0.000    0.000    0.007    0.000 series.py:5627(_logical_method)
#       680    0.000    0.000    0.001    0.000 series.py:575(dtype)
#      1260    0.000    0.000    0.000    0.000 series.py:590(name)
#       540    0.000    0.000    0.001    0.000 series.py:640(name)
#       780    0.000    0.000    0.000    0.000 series.py:687(_values)
#        30    0.000    0.000    0.000    0.000 series.py:743(__len__)
#       150    0.000    0.000    0.000    0.000 series.py:825(__array__)
#        10    0.000    0.000    0.000    0.000 series.py:885(axes)
#        40    0.000    0.000    0.000    0.000 shape_base.py:19(_atleast_1d_dispatcher)
#        10    0.000    0.000    0.000    0.000 shape_base.py:207(_arrays_for_stack_dispatcher)
#        10    0.000    0.000    0.000    0.000 shape_base.py:218(_vhstack_dispatcher)
#        10    0.000    0.000    0.001    0.000 shape_base.py:222(vstack)
#        40    0.000    0.000    0.000    0.000 shape_base.py:23(atleast_1d)
#        20    0.000    0.000    0.000    0.000 shape_base.py:77(_atleast_2d_dispatcher)
#        20    0.001    0.000    0.001    0.000 shape_base.py:81(atleast_2d)
#        40    0.000    0.000    0.000    0.000 six.py:601(itervalues)
#       120    0.000    0.000    0.000    0.000 six.py:604(iteritems)
#        30    0.000    0.000    0.000    0.000 take.py:120(_take_nd_ndarray)
#        30    0.000    0.000    0.000    0.000 take.py:326(_get_take_nd_function)
#        30    0.000    0.000    0.000    0.000 take.py:554(_take_preprocess_indexer_and_fill_value)
#        30    0.000    0.000    0.000    0.000 take.py:57(take_nd)
#        40    0.000    0.000    0.000    0.000 types.py:171(__get__)
#      3280    0.000    0.000    0.000    0.000 typing.py:1375(cast)
#       130    0.000    0.000    0.012    0.000 util.py:159(atleast_2d_column_default)
#        10    0.000    0.000    0.000    0.000 util.py:556(safe_scalar_isnan)
#        10    0.000    0.000    0.000    0.000 util.py:583(iterable)
#       180    0.000    0.000    0.001    0.000 util.py:669(safe_is_pandas_categorical_dtype)
#        10    0.000    0.000    0.000    0.000 util.py:675(safe_is_pandas_categorical)
#       170    0.000    0.000    0.001    0.000 util.py:707(safe_issubdtype)
#        10    0.000    0.000    0.000    0.000 utils.py:249(maybe_convert_indices)
#        10    0.000    0.000    0.000    0.000 utils.py:457(check_array_indexer)
#        20    0.000    0.000    0.000    0.000 utils.py:69(is_list_like_indexer)
#        40    0.000    0.000    0.000    0.000 warnings.py:130(filterwarnings)
#        40    0.000    0.000    0.000    0.000 warnings.py:181(_add_filter)
#        40    0.000    0.000    0.000    0.000 warnings.py:437(__init__)
#        40    0.000    0.000    0.000    0.000 warnings.py:458(__enter__)
#        40    0.000    0.000    0.000    0.000 warnings.py:477(__exit__)
#     20/10    0.000    0.000    0.000    0.000 wrapper.py:21(__getattribute__)
#        40    0.000    0.000    0.000    0.000 wrapper.py:22(<lambda>)
#       280    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x100870a50}
#       240    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#        10    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#        10    0.000    0.000    0.000    0.000 {built-in method _operator.eq}
#        10    0.000    0.000    0.000    0.000 {built-in method _operator.invert}
#       210    0.000    0.000    0.000    0.000 {built-in method _operator.or_}
#        10    0.000    0.000    0.000    0.000 {built-in method _simple_new}
#       120    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#       890    0.000    0.000    0.002    0.000 {built-in method builtins.all}
#        70    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#       260    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#       110    0.001    0.000    0.001    0.000 {built-in method builtins.compile}
#       110    0.000    0.000    0.004    0.000 {built-in method builtins.eval}
#         1    0.000    0.000    0.133    0.133 {built-in method builtins.exec}
# 9630/9610    0.001    0.000    0.001    0.000 {built-in method builtins.getattr}
#      3040    0.000    0.000    0.001    0.000 {built-in method builtins.hasattr}
#      2910    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#     60470    0.006    0.000    0.008    0.000 {built-in method builtins.isinstance}
#      9310    0.001    0.000    0.001    0.000 {built-in method builtins.issubclass}
#       180    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
# 16780/12910    0.002    0.000    0.003    0.000 {built-in method builtins.len}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        10    0.000    0.000    0.005    0.000 {built-in method builtins.sorted}
#       640    0.000    0.000    0.001    0.000 {built-in method builtins.sum}
#        10    0.000    0.000    0.000    0.000 {built-in method fromkeys}
#      2550    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#      2240    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
# 1340/1110    0.001    0.000    0.002    0.000 {built-in method numpy.asarray}
#   430/410    0.002    0.000    0.013    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        10    0.000    0.000    0.000    0.000 {built-in method numpy.datetime_data}
#       500    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#       440    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#       220    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#       120    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#       100    0.000    0.000    0.000    0.000 {built-in method pandas._libs.internals.slice_len}
#        10    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.checknull}
#        10    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslib.array_to_datetime}
#        10    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslibs.timezones.maybe_get_tz}
#        10    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#        30    0.000    0.000    0.000    0.000 {method '_rebuild_blknos_and_blklocs' of 'pandas._libs.internals.BlockManager' objects}
#        10    0.000    0.000    0.000    0.000 {method '_set_freq' of 'pandas._libs.tslibs.timestamps._Timestamp' objects}
#       110    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#       120    0.000    0.000    0.001    0.000 {method 'any' of 'numpy.ndarray' objects}
#      2920    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#        10    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#       670    0.001    0.000    0.001    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        10    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#       200    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#       100    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#       100    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        20    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#       340    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        20    0.000    0.000    0.000    0.000 {method 'get_indexer' of 'pandas._libs.index.IndexEngine' objects}
#       110    0.000    0.000    0.000    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#        11    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#        40    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#        70    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#       160    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#       120    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#       100    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#        10    0.000    0.000    0.000    0.000 {method 'max' of 'numpy.ndarray' objects}
#       220    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        10    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#        20    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#       260    0.001    0.000    0.001    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        40    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#        10    0.000    0.000    0.000    0.000 {method 'repeat' of 'numpy.ndarray' objects}
#      2410    0.001    0.000    0.001    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#        20    0.000    0.000    0.000    0.000 {method 'reshape' of 'pandas._libs.arrays.NDArrayBacked' objects}
#       610    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#       100    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#        10    0.000    0.000    0.000    0.000 {method 'sum' of 'numpy.ndarray' objects}
#        30    0.000    0.000    0.000    0.000 {method 'take' of 'numpy.ndarray' objects}
#       100    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#       110    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#        40    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#        40    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#        30    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#      2190    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_object}
#        80    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_platform_int}
#        20    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_1d_int64_int64}
#        10    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_2d_axis1_object_object}
#        10    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_blkno_placements}
#        10    0.000    0.000    0.000    0.000 {pandas._libs.lib.astype_intsafe}
#        10    0.000    0.000    0.000    0.000 {pandas._libs.lib.dtypes_all_equal}
#      2190    0.001    0.000    0.001    0.000 {pandas._libs.lib.infer_datetimelike_array}
#        40    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_dtype}
#        10    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_all_arraylike}
#        10    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool_list}
#       200    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#       340    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#       290    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#       300    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_iterator}
#      1490    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#       710    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#       670    0.000    0.000    0.000    0.000 {pandas._libs.lib.item_from_zerodim}
#       190    0.002    0.000    0.003    0.000 {pandas._libs.lib.maybe_convert_objects}
#       320    0.000    0.000    0.014    0.000 {pandas._libs.ops_dispatch.maybe_dispatch_ufunc_to_dunder_op}
